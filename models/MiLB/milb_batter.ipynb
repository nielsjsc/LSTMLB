# %%
# Core libraries
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

# Data processing and analysis
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import joblib
from typing import Tuple, List, Optional, NamedTuple, Dict
from dataclasses import dataclass, asdict, field




# Progress tracking and logging
from tqdm import tqdm
import logging

# Random seed
import random

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Set random seeds for reproducibility
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

INPUT_FEATURES = [
                # Prospect Evaluation
                'Top 100', 'FV',
                # Scouting Grades (need to convert from string format)
                #'Hit', 'Game', 'Raw', 'Spd', 'FV','Age', 
                # Minor League Performance
                #'PA', 'OBP', 'SLG', 'ISO', 'BB%', 'K%', 'wRC+'
            ]

TARGET_FEATURES = [
    # Overall Value
    'WAR_150',       
    
    
]

SEQ_LENGTH = 1

# %%
# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

   
@dataclass
class DataConfig:
    seq_length: int = SEQ_LENGTH
    start_season: int = 2002
    min_pa: int = 20
    input_features: List[str] = None
    target_features: List[str] = None  # Add target features
    train_ratio: float = 0.75
    valid_ratio: float = 0.24
    random_seed: int = 42
    input_weights: Dict[str, float] = field(default_factory=lambda: {

        
        # Prospect ratings (higher weight for younger players)
        'FV': 1.0,
        # Rankings (moderate weight)
        'Top 100': 1.0,

        

    })
    
    def __post_init__(self):
        if self.input_features is None:
            self.input_features = INPUT_FEATURES
        if self.target_features is None:
            self.target_features = TARGET_FEATURES

    
class SequenceHandler:
    def __init__(self, seq_length: int, feature_dim: int, pad_value: float = 0.0):
        self.seq_length = seq_length
        self.feature_dim = feature_dim
        self.pad_value = pad_value
        
    def create_sequence(self, player_data: pd.DataFrame, input_features: List[str]) -> Tuple[np.ndarray, torch.Tensor]:
        available_seasons = len(player_data)
        
        # Convert input features to numeric, replacing any non-numeric values with 0 instead of NaN
        numeric_data = player_data[input_features].apply(pd.to_numeric, errors='coerce').fillna(0)
        
        if available_seasons >= self.seq_length:
            sequence = numeric_data.iloc[-self.seq_length:].values
            mask = torch.ones(self.seq_length, dtype=torch.bool)
        else:
            # Create padding with zeros instead of NaN
            padding_size = self.seq_length - available_seasons
            real_data = numeric_data.values
            padding = np.zeros((padding_size, len(input_features)))  # Use zeros instead of pad_value
            sequence = np.vstack([padding, real_data])
            mask = torch.zeros(self.seq_length, dtype=torch.bool)
            mask[padding_size:] = 1
        
        return sequence.astype(np.float32), mask
        
        return sequence, mask

def calculate_rate_stats(df: pd.DataFrame) -> pd.DataFrame:
    """Calculate rate statistics including WAR/150"""
    df = df.copy()
    
    # Base running rates (per Game)
    if 'HR' in df.columns:
        df['HR_rate'] = df['HR'] / df['G']
    if '2B' in df.columns:
        df['2B_rate'] = df['2B'] / df['G']
    if '3B' in df.columns:
        df['3B_rate'] = df['3B'] / df['G']
    if 'RBI' in df.columns:
        df['RBI_rate'] = df['RBI'] / df['G']
    if 'R' in df.columns:
        df['R_rate'] = df['R'] / df['G']
        
    # Calculate WAR/150
    if 'WAR' in df.columns and 'G' in df.columns:
        df['WAR_150'] = (df['WAR'] / df['G']) * 150
    
    # Replace infinities and NaN with 0
    rate_columns = [col for col in df.columns if col.endswith('_rate') or col == 'WAR_150']
    df[rate_columns] = df[rate_columns].replace([np.inf, -np.inf], 0).fillna(0)
    
    return df

def estimate_top_100(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    
    for year in df['Year'].unique():
        year_data = df[df['Year'] == year]
        
        # Analysis for this year
        total_prospects = len(year_data)
        fv_distribution = year_data['FV'].value_counts().sort_index()
        top_100_min_fv = year_data[year_data['Top 100'] > 0]['FV'].min()
        
        logger.info(f"\nYear {year}:")
        logger.info(f"Total prospects: {total_prospects}")
        logger.info(f"FV distribution:\n{fv_distribution}")
        logger.info(f"Minimum FV in Top 100: {top_100_min_fv}")
        
        # Simple FV-based ranking
        # Find prospects not in Top 100
        mask = (year_data['Top 100'] == 0) | (year_data['Top 100'].isna())
        unranked = year_data[mask].copy()
        
        if not unranked.empty:
            # Sort by FV descending
            unranked = unranked.sort_values('FV', ascending=False)
            # Assign ranks from 101 to max
            ranks = range(101, 101 + len(unranked))
            unranked.loc[:, 'Top 100'] = ranks
            
            # Update original dataframe
            df.update(unranked['Top 100'])
    
    return df
def validate_features(df: pd.DataFrame, features: List[str]) -> None:
    """Validate that all required features exist in dataframe"""
    missing_features = [f for f in features if f not in df.columns]
    if missing_features:
        raise ValueError(f"Missing required features: {missing_features}")

def load_data(data_config: DataConfig) -> Tuple[pd.DataFrame, pd.DataFrame]:
    mlb_df = pd.read_csv('data/raw/batters/MLB_BATTING_DATA_2000_2024.csv')
    mlb_df['IDfg'] = mlb_df['IDfg'].astype(str)
    mlb_df = calculate_rate_stats(mlb_df)
    
    prospect_dfs = []
    for year in range(2017, 2025):
        try:
            df = pd.read_csv(f'data/raw/batters/{year}.csv')
            df['Year'] = year
            df = df.rename(columns={'playerId': 'IDfg'})
            
            # Convert grades to numeric
            for col in ['Hit', 'Game', 'Raw', 'Spd', 'FV']:
                df[col] = df[col].apply(extract_grade)
            prospect_dfs.append(df)
        except FileNotFoundError:
            logger.warning(f"No prospect data found for {year}")
    
    prospect_df = pd.concat(prospect_dfs, ignore_index=True)
    return prospect_df, mlb_df

    
    return prospect_df, mlb_df
def split_data(sequences: List[Tuple], 
               masks: List[torch.Tensor],
               targets: List[np.ndarray],
               train_ratio: float,
               valid_ratio: float) -> Tuple:
    """Split data into train, validation and test sets"""
    # Validate ratios
    if not 0 < train_ratio + valid_ratio < 1:
        raise ValueError("Train and validation ratios must sum to less than 1")
    
    logger.info("Splitting data into train, validation, and test sets")
    n = len(sequences)
    indices = np.random.permutation(n)
    
    train_size = int(n * train_ratio)
    valid_size = int(n * valid_ratio)
    
    train_indices = indices[:train_size]
    valid_indices = indices[train_size:train_size + valid_size]
    test_indices = indices[train_size + valid_size:]
    
    # Split sequences, masks AND targets
    train_data = (
        [sequences[i] for i in train_indices], 
        [masks[i] for i in train_indices],
        [targets[i] for i in train_indices]
    )
    
    valid_data = (
        [sequences[i] for i in valid_indices], 
        [masks[i] for i in valid_indices],
        [targets[i] for i in valid_indices]
    )
    
    test_data = (
        [sequences[i] for i in test_indices], 
        [masks[i] for i in test_indices],
        [targets[i] for i in test_indices]
    )
    
    logger.info(f"Split sizes - Train: {len(train_indices)}, Valid: {len(valid_indices)}, Test: {len(test_indices)}")
    
    return train_data, valid_data, test_data
def filter_data(df: pd.DataFrame, min_pa: int) -> pd.DataFrame:
    """Filter data and estimate Top 100 values"""
    logger.info("Filtering data...")
    initial_size = len(df)
    
    # Filter by minimum PA
    df = df[df['PA'] >= min_pa]
    #filter by year
    df = df[df['Year'] <= 2021]
    
    # Estimate Top 100 values
    df = estimate_top_100(df)
    
    logger.info(f"Filtered from {initial_size} to {len(df)} rows")
    return df

def convert_column_types(df: pd.DataFrame, features: List[str]) -> pd.DataFrame:
    """Convert columns to float32 for LSTM compatibility"""
    logger.info("Converting column types...")
    
    for col in features:
        try:
            # Convert percentage strings to floats if needed
            if df[col].dtype == object and df[col].str.contains('%').any():
                df[col] = df[col].str.rstrip('%').astype('float32') / 100
            else:
                df[col] = df[col].astype('float32')
        except Exception as e:
            logger.error(f"Error converting column {col}: {str(e)}")
            raise
            
    return df

from sklearn.preprocessing import MinMaxScaler

def scale_features(df: pd.DataFrame, 
                  features: List[str],
                  scaler: Optional[MinMaxScaler] = None) -> Tuple[pd.DataFrame, MinMaxScaler]:
    """Scale only input features for prospect data"""
    if scaler is None:
        scaler = MinMaxScaler(feature_range=(-1, 1))
        scaler.fit(df[features].fillna(0))
        joblib.dump(scaler, 'milb_batter_input_scaler.pkl')
        logger.info("Created new MinMaxScaler")
    
    scaled_data = scaler.transform(df[features].fillna(0))
    
    # Update DataFrame with scaled values
    for i, feature in enumerate(features):
        df[feature] = scaled_data[:, i]
        
    return df, scaler

def scale_mlb_targets(mlb_df: pd.DataFrame,
                     target_features: List[str],
                     target_scaler: Optional[MinMaxScaler] = None) -> Tuple[pd.DataFrame, MinMaxScaler]:
    """Scale MLB target features separately"""
    if target_scaler is None:
        target_scaler = MinMaxScaler(feature_range=(-1, 1))
        target_scaler.fit(mlb_df[target_features].fillna(0))
        joblib.dump(target_scaler, 'milb_batter_target_scaler.pkl')
        logger.info("Created new target MinMaxScaler")
    
    scaled_targets = target_scaler.transform(mlb_df[target_features].fillna(0))
    
    # Update DataFrame with scaled values
    for i, feature in enumerate(target_features):
        mlb_df[feature] = scaled_targets[:, i]
        
    return mlb_df, target_scaler


    



def extract_grade(grade_str):
    """Extract numeric grade, handling + modifiers"""
    if pd.isna(grade_str):
        return None
    try:
        # Handle direct numeric values
        if isinstance(grade_str, (int, float)):
            return float(grade_str)
            
        grade_str = str(grade_str)
        if '/' in grade_str:
            grade_str = grade_str.split('/')[1].strip()
            
        # Handle + modifier
        if '+' in grade_str:
            return float(grade_str.replace('+', '')) + 2.5
            
        return float(grade_str)
    except:
        return None
def prepare_sequences_with_mlb(prospect_df: pd.DataFrame, 
                             mlb_df: pd.DataFrame,
                             input_features: List[str],
                             target_features: List[str],
                             seq_length: int) -> Tuple[List, List, List]:
    sequences = []
    masks = []
    targets = []
    handler = SequenceHandler(seq_length, len(input_features))
    
    for player_id, player_data in prospect_df.groupby('IDfg'):
        mlb_outcome = mlb_df[mlb_df['IDfg'] == player_id]
        
        if len(mlb_outcome) == 0:
            continue
            
        # Check if any target features are NaN
        if mlb_outcome[target_features].isna().any().any():
            continue
            
        sequence, mask = handler.create_sequence(player_data, input_features)
        
        if not (np.isnan(sequence).any() or np.isinf(sequence).any()):
            sequences.append(sequence)
            masks.append(mask)
            targets.append(mlb_outcome[target_features].values[0])
            
            # Debug first few sequences
            if len(sequences) <= 3:
                logger.info(f"Sequence {len(sequences)} shape: {sequence.shape}")
                logger.info(f"Mask {len(sequences)} shape: {mask.shape}")
    
    # Final shape check
    if sequences:
        logger.info(f"Final sequence shape: {sequences[0].shape}")
        logger.info(f"Total sequences: {len(sequences)}")
        logger.info(f"Total elements: {sum(s.size for s in sequences)}")
    
    return sequences, masks, targets

def to_tensor(sequences: List[np.ndarray], masks: List[torch.Tensor], targets: List[np.ndarray]) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
    """Convert sequences, masks and targets to properly shaped tensors"""
    # Convert sequences to tensor, maintaining sequence structure
    X = torch.FloatTensor([seq for seq in sequences])  # [batch, seq_len, features]
    masks = torch.stack(masks)  # [batch, seq_len]
    y = torch.FloatTensor(targets)  # [batch, target_features]
    
    # Debug shapes
    logger.info(f"Sequence tensor shape: {X.shape}")
    logger.info(f"Mask tensor shape: {masks.shape}")
    logger.info(f"Target tensor shape: {y.shape}")
    
    if torch.isnan(X).any():
        raise ValueError("NaN values found in input sequences")
    
    return X, masks, y


def preprocess_data(data_config: DataConfig) -> Tuple[torch.Tensor, ...]:
    """Updated preprocessing pipeline"""
    # Load data
    prospect_df, mlb_df = load_data(data_config)
    
    # Scale input features (prospects)
    filtered_df, input_scaler = scale_features(
        filter_data(prospect_df, min_pa=data_config.min_pa),
        data_config.input_features
    )
    
    # Scale target features (MLB outcomes)
    mlb_df, target_scaler = scale_mlb_targets(mlb_df, data_config.target_features)
    
    # Create sequences with scaled data
    sequences, masks, targets = prepare_sequences_with_mlb(
        prospect_df=filtered_df,
        mlb_df=mlb_df,
        input_features=data_config.input_features,
        target_features=data_config.target_features,
        seq_length=data_config.seq_length
    )
    
    # Split data
    train_data, valid_data, test_data = split_data(
        sequences, masks, targets,
        train_ratio=data_config.train_ratio,
        valid_ratio=data_config.valid_ratio
    )
    
    # Convert to tensors
    train_tensors = to_tensor(train_data[0], train_data[1], train_data[2])
    valid_tensors = to_tensor(valid_data[0], valid_data[1], valid_data[2])
    test_tensors = to_tensor(test_data[0], test_data[1], test_data[2])
    
    return train_tensors, valid_tensors, test_tensors, input_scaler, target_scaler
    



# Initialize configuration with all features
data_config = DataConfig(
    input_features=INPUT_FEATURES,
    target_features=['WAR_150']  # Only predicting WAR now
)


data = preprocess_data(data_config)
# Out:
# INFO:__main__:Filtering data...
# INFO:__main__:
# Year 2017:
# INFO:__main__:Total prospects: 323
# INFO:__main__:FV distribution:
# FV
# 40.0    162
# 45.0     92
# 50.0     30
# 55.0     24
# 60.0     10
# 65.0      4
# 70.0      1
# Name: count, dtype: int64
# INFO:__main__:Minimum FV in Top 100: 50.0
# INFO:__main__:
# Year 2018:
# INFO:__main__:Total prospects: 354
# INFO:__main__:FV distribution:
# FV
# 40.0    181
# 45.0     96
# 50.0     52
# 55.0      9
# 60.0     11
# 65.0      5
# Name: count, dtype: int64
# INFO:__main__:Minimum FV in Top 100: 50.0
# INFO:__main__:
# Year 2019:
# INFO:__main__:Total prospects: 478
# INFO:__main__:FV distribution:
# FV
# 37.5     87
# 40.0    181
# 42.5     49
# 45.0     59
# 47.5     20
# 50.0     54
# 55.0     12
# 60.0     11
# 65.0      4
# 70.0      1
# Name: count, dtype: int64
# INFO:__main__:Minimum FV in Top 100: 50.0
# INFO:__main__:
# Year 2020:
# INFO:__main__:Total prospects: 117
# INFO:__main__:FV distribution:
# FV
# 37.5    13
# 40.0    38
# 42.5    11
# 45.0    16
# 47.5     5
# 50.0    18
# 55.0     8
# 60.0     6
# 65.0     1
# 70.0     1
# Name: count, dtype: int64
# INFO:__main__:Minimum FV in Top 100: 50.0
# INFO:__main__:
# Year 2021:
# INFO:__main__:Total prospects: 575
# INFO:__main__:FV distribution:
# FV
# 37.5    133
# 40.0    179
# 42.5     82
# 45.0     80
# 47.5     18
# 50.0     51
# 55.0     14
# 60.0     16
# 65.0      1
# 80.0      1
# Name: count, dtype: int64
# INFO:__main__:Minimum FV in Top 100: 50.0
# INFO:__main__:Filtered from 3757 to 1847 rows
# INFO:__main__:Created new MinMaxScaler
# INFO:__main__:Created new target MinMaxScaler
# INFO:__main__:Sequence 1 shape: (1, 2)
# INFO:__main__:Mask 1 shape: torch.Size([1])
# INFO:__main__:Sequence 2 shape: (1, 2)
# INFO:__main__:Mask 2 shape: torch.Size([1])
# INFO:__main__:Sequence 3 shape: (1, 2)
# INFO:__main__:Mask 3 shape: torch.Size([1])
# INFO:__main__:Final sequence shape: (1, 2)
# INFO:__main__:Total sequences: 580
# INFO:__main__:Total elements: 1160
# INFO:__main__:Splitting data into train, validation, and test sets
# INFO:__main__:Split sizes - Train: 435, Valid: 139, Test: 6
# INFO:__main__:Sequence tensor shape: torch.Size([435, 1, 2])
# INFO:__main__:Mask tensor shape: torch.Size([435, 1])
# INFO:__main__:Target tensor shape: torch.Size([435, 1])
# INFO:__main__:Sequence tensor shape: torch.Size([139, 1, 2])
# INFO:__main__:Mask tensor shape: torch.Size([139, 1])
# INFO:__main__:Target tensor shape: torch.Size([139, 1])
# INFO:__main__:Sequence tensor shape: torch.Size([6, 1, 2])
# INFO:__main__:Mask tensor shape: torch.Size([6, 1])
# INFO:__main__:Target tensor shape: torch.Size([6, 1])

# %%
class MultiHeadAttention(nn.Module):
    def __init__(
        self, 
        hidden_size: int,
        num_heads: int = 8,
        dropout: float = 0.1,
        bias: bool = True
    ):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_heads = num_heads
        self.head_dim = hidden_size // num_heads
        self.scaling = self.head_dim ** -0.5
        
        assert self.head_dim * num_heads == hidden_size, "hidden_size must be divisible by num_heads"
        
        # Linear projections
        self.q_proj = nn.Linear(hidden_size, hidden_size, bias=bias)
        self.k_proj = nn.Linear(hidden_size, hidden_size, bias=bias)
        self.v_proj = nn.Linear(hidden_size, hidden_size, bias=bias)
        self.out_proj = nn.Linear(hidden_size, hidden_size, bias=bias)
        
        # Dropout
        self.dropout = nn.Dropout(dropout)
        
        # Initialize parameters
        self._reset_parameters()
    
    def _reset_parameters(self):
        # Use Xavier uniform initialization
        nn.init.xavier_uniform_(self.q_proj.weight)
        nn.init.xavier_uniform_(self.k_proj.weight)
        nn.init.xavier_uniform_(self.v_proj.weight)
        nn.init.xavier_uniform_(self.out_proj.weight)
        if self.q_proj.bias is not None:
            nn.init.zeros_(self.q_proj.bias)
            nn.init.zeros_(self.k_proj.bias)
            nn.init.zeros_(self.v_proj.bias)
            nn.init.zeros_(self.out_proj.bias)
    
    def forward(
        self,
        query: torch.Tensor,
        key: Optional[torch.Tensor] = None,
        value: Optional[torch.Tensor] = None,
        key_padding_mask: Optional[torch.Tensor] = None,
        need_weights: bool = False
    ) -> Tuple[torch.Tensor, Optional[torch.Tensor]]:
        # Set key and value to query if not provided
        if key is None:
            key = query
        if value is None:
            value = query
            
        batch_size, seq_len, _ = query.size()
        
        # Project inputs
        q = self.q_proj(query)
        k = self.k_proj(key)
        v = self.v_proj(value)
        
        # Reshape for multi-head attention
        q = q.view(batch_size, seq_len, self.num_heads, self.head_dim).transpose(1, 2)
        k = k.view(batch_size, -1, self.num_heads, self.head_dim).transpose(1, 2)
        v = v.view(batch_size, -1, self.num_heads, self.head_dim).transpose(1, 2)
        
        # Compute attention scores
        attn_weights = torch.matmul(q, k.transpose(-2, -1)) * self.scaling
        
        # Apply key padding mask if provided
        if key_padding_mask is not None:
            attn_weights = attn_weights.masked_fill(
                key_padding_mask.unsqueeze(1).unsqueeze(2),
                float('-inf')
            )
        
        # Apply softmax and dropout
        attn_weights = F.softmax(attn_weights, dim=-1)
        attn_weights = self.dropout(attn_weights)
        
        # Get attention output
        attn_output = torch.matmul(attn_weights, v)
        
        # Reshape and project output
        attn_output = attn_output.transpose(1, 2).contiguous()
        attn_output = attn_output.view(batch_size, seq_len, self.hidden_size)
        attn_output = self.out_proj(attn_output)
        
        if need_weights:
            return attn_output, attn_weights
        return attn_output, None

# %%
class ResidualBlock(nn.Module):
    def __init__(self, hidden_size: int, dropout: float = 0.1):
        super().__init__()
        self.layer_norm = nn.LayerNorm(hidden_size)
        self.layers = nn.Sequential(
            nn.Linear(hidden_size, hidden_size * 4),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_size * 4, hidden_size)
        )
        
    def forward(self, x: torch.Tensor) -> torch.Tensor:
        return x + self.layers(self.layer_norm(x))

class ImprovedLSTM(nn.Module):
    def __init__(
        self, 
        input_size: int,
        hidden_size: int = 512,
        num_layers: int = 4,
        output_size: int = None,
        dropout: float = 0.3,
        bidirectional: bool = True,
        num_heads: int = 8,  # Keep this parameter for compatibility
        feature_weights: Optional[Dict[str, float]] = None
    ):
        super().__init__()
        
        self.input_size = input_size
        self.hidden_size = hidden_size // 2  # Reduce internal hidden size
        self.num_layers = 2  # Use fewer layers internally
        self.output_size = output_size or input_size
        self.bidirectional = bidirectional
        self.directions = 2 if bidirectional else 1
        
        self.feature_weights = feature_weights
        if feature_weights is not None:
            self.feature_weight_tensor = nn.Parameter(
                torch.tensor([feature_weights.get(f, 1.0) for f in INPUT_FEATURES], 
                           dtype=torch.float32).view(1, 1, -1),
                requires_grad=False
            )
        # Learned padding token
        self.pad_token = nn.Parameter(torch.randn(1, 1, input_size))
        
        # Input projection with Layer Normalization
        self.input_projection = nn.Sequential(
            nn.Linear(input_size, self.hidden_size),
            nn.LayerNorm(self.hidden_size),
            nn.GELU()
        )
        
        # LSTM layers with residual connections and layer normalization
        self.lstm_layers = nn.ModuleList([
            nn.ModuleDict({
                'lstm': nn.LSTM(
                    self.hidden_size * self.directions if i > 0 else self.hidden_size,
                    self.hidden_size,
                    num_layers=1,
                    batch_first=True,
                    bidirectional=bidirectional
                ),
                'norm': nn.LayerNorm(self.hidden_size * self.directions),
                'dropout': nn.Dropout(dropout/2)  # Reduce dropout
            }) for i in range(self.num_layers)
        ])
        
        # Attention mechanism
        self.attention = MultiHeadAttention(
            self.hidden_size * self.directions,
            num_heads=4,  # Reduced from num_heads parameter
            dropout=dropout/2
        )
        
        # Output projection
        self.output_projection = nn.Sequential(
            nn.Linear(self.hidden_size * self.directions, hidden_size),
            nn.LayerNorm(hidden_size),
            nn.GELU(),
            nn.Dropout(dropout/2),
            nn.Linear(hidden_size, self.output_size)
        )

    def forward(self, x: torch.Tensor, lengths: torch.Tensor) -> torch.Tensor:
        batch_size, seq_len, _ = x.size()
        if hasattr(self, 'feature_weight_tensor'):
            x = x * self.feature_weight_tensor.expand(batch_size, seq_len, -1)
        # Replace zero padding with learned padding token
        padding_mask = (x.sum(dim=-1) == 0).unsqueeze(-1)
        x = torch.where(padding_mask, self.pad_token.expand(batch_size, seq_len, -1), x)
        
        # Create attention mask
        attention_mask = torch.arange(seq_len, device=x.device)[None, :] < lengths[:, None]
        
        # Input projection
        x = self.input_projection(x)
        
        # Process LSTM layers with residual connections
        for layer in self.lstm_layers:
            # Pack padded sequence
            packed_x = pack_padded_sequence(
                x, lengths.cpu(),
                batch_first=True,
                enforce_sorted=False
            )
            
            # LSTM forward pass
            lstm_out, _ = layer['lstm'](packed_x)
            lstm_out, _ = pad_packed_sequence(
                lstm_out,
                batch_first=True,
                total_length=seq_len
            )
            
            # Apply normalization and dropout
            lstm_out = layer['norm'](lstm_out)
            lstm_out = layer['dropout'](lstm_out)
            
            # Residual connection if shapes match
            if lstm_out.size(-1) == x.size(-1):
                x = x + lstm_out
            else:
                x = lstm_out
        
        # Apply attention with proper masking
        attended, _ = self.attention(
            x, x, x,
            key_padding_mask=~attention_mask
        )
        
        # Get final states using sequence lengths
        batch_indices = torch.arange(batch_size, device=x.device)
        final_states = attended[batch_indices, lengths - 1]
        
        # Project to output size
        output = self.output_projection(final_states)
        
        return output

# %%
#Model configuration
# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

class DataBatch(NamedTuple):
    """Container for training data batches."""
    train: TensorDataset
    valid: TensorDataset
    test: TensorDataset

@dataclass
class Config:
    """Advanced configuration for LSTM-based baseball statistics prediction."""
    
    # Dynamic sizes from data
    input_size: int = None
    output_size: int = None
    
    # Model Architecture 
    hidden_size: int = 256
    num_layers: int = 4
    num_heads: int = 4
    bidirectional: bool = True
    attention_dropout: float = 0.1
    residual_dropout: float = 0.2
    layer_norm_eps: float = 1e-5
    
    # Training Parameters
    batch_size: int = 8
    dropout: float = 0.3
    learning_rate: float = 1e-4
    weight_decay: float = 1e-5
    gradient_clip: float = 1.0
    num_epochs: int = 50
    warmup_epochs: int = 5
    
    # Learning Rate Schedule
    lr_schedule: str = 'cosine'
    min_lr: float = 1e-6
    lr_decay_rate: float = 0.1
    lr_patience: int = 5
    
    # Early Stopping
    early_stopping_patience: int = 10
    early_stopping_min_delta: float = 1e-4
    
    # Loss Function Parameters
    diversity_alpha: float = 0.1  # Weight for diversity penalty
    consistency_beta: float = 0.05  # Weight for consistency penalty
    
    # Hardware Optimization
    mixed_precision: bool = True
    num_workers: int = 0
    pin_memory: bool = True
    
    # Logging
    log_interval: int = 100
    checkpoint_interval: int = 1
    
    def __init__(self, X_train: torch.Tensor, y_train: torch.Tensor):
        self.input_size = X_train.shape[2]
        self.output_size = y_train.shape[1]
        self._validate_config()
        self._log_config()
    
    def _validate_config(self) -> None:
        assert self.hidden_size % self.num_heads == 0, \
            "Hidden size must be divisible by number of attention heads"
        assert self.hidden_size >= self.input_size, \
            "Hidden size must be greater than or equal to input size"
        assert 0 <= self.dropout <= 1, "Dropout must be between 0 and 1"
        assert self.num_layers >= 1, "Must have at least one LSTM layer"
        assert self.batch_size > 0, "Batch size must be positive"
        assert self.learning_rate > 0, "Learning rate must be positive"
        assert self.lr_schedule in ['cosine', 'linear', 'exponential'], \
            "Invalid learning rate schedule"
        assert 0 <= self.diversity_alpha <= 1, "Diversity alpha must be between 0 and 1"
        assert 0 <= self.consistency_beta <= 1, "Consistency beta must be between 0 and 1"
    
    def _log_config(self) -> None:
        logger.info("Model Configuration:")
        for key, value in asdict(self).items():
            logger.info(f"{key}: {value}")
    
    @property
    def device(self) -> torch.device:
        return torch.device('cuda' if torch.cuda.is_available() else 'cpu')

class PlayerDifferentiationLoss(nn.Module):
    def __init__(self, alpha: float = 0.1, beta: float = 0.05):
        super().__init__()
        self.mse = nn.MSELoss()
        self.alpha = alpha
        self.beta = beta

    def forward(self, predictions: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
        # Base MSE loss
        mse_loss = self.mse(predictions, targets)
        
        # Diversity penalty - encourage different predictions within batch
        batch_mean = predictions.mean(dim=0, keepdim=True)
        diversity_loss = -torch.mean(torch.abs(predictions - batch_mean))
        
        # Consistency penalty - predictions should be stable
        pred_std = predictions.std(dim=0).mean()
        consistency_loss = torch.abs(pred_std - targets.std(dim=0).mean())
        
        # Combine losses
        total_loss = mse_loss + self.alpha * diversity_loss + self.beta * consistency_loss
        
        return total_loss
    
    @property
    def device(self) -> torch.device:
        """Get appropriate device for training."""
        return torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def create_data_loaders(data_tuple: tuple) -> DataBatch:
    """Create data loaders from preprocessed data tuple"""
    # Unpack all values correctly
    train_tensors, valid_tensors, test_tensors, input_scaler, target_scaler = data_tuple
    
    # Reshape tensors to (batch_size, seq_length, features)
    X_train = train_tensors[0].unsqueeze(1)  # Add sequence dimension
    X_valid = valid_tensors[0].unsqueeze(1)
    X_test = test_tensors[0].unsqueeze(1)
    
    # Create datasets with reshaped tensors
    train_dataset = TensorDataset(X_train, train_tensors[1], train_tensors[2])
    valid_dataset = TensorDataset(X_valid, valid_tensors[1], valid_tensors[2])
    test_dataset = TensorDataset(X_test, test_tensors[1], test_tensors[2])
    
    logger.info(f"Reshaped train tensor: {X_train.shape}")
    
    return DataBatch(train_dataset, valid_dataset, test_dataset)


# Initialize everything
try:
    # Create data loaders
    data_batch = create_data_loaders(data)
    
    # Initialize config
    config = Config(
        X_train=data_batch.train.tensors[0],  # Input features
        y_train=data_batch.train.tensors[2]   # Target values
    )
    
    # Create DataLoaders
    train_loader = DataLoader(
        data_batch.train,
        batch_size=config.batch_size,
        shuffle=True,
        num_workers=config.num_workers,
        pin_memory=config.pin_memory
    )
    
    valid_loader = DataLoader(
        data_batch.valid,
        batch_size=config.batch_size,
        shuffle=False,
        num_workers=config.num_workers,
        pin_memory=config.pin_memory
    )
    
    test_loader = DataLoader(
        data_batch.test,
        batch_size=config.batch_size,
        shuffle=False,
        num_workers=config.num_workers,
        pin_memory=config.pin_memory
    )

    # Initialize model
    model = ImprovedLSTM(
        input_size=len(INPUT_FEATURES),
        hidden_size=config.hidden_size,
        num_layers=config.num_layers,
        output_size=len(TARGET_FEATURES),
        dropout=config.dropout,
        bidirectional=config.bidirectional,
        num_heads=config.num_heads,
        feature_weights=data_config.input_weights
    )
    
    # Initialize optimizer
    optimizer = optim.AdamW(
        model.parameters(),
        lr=config.learning_rate,
        weight_decay=config.weight_decay
    )
    
    # Initialize learning rate scheduler
    scheduler = optim.lr_scheduler.OneCycleLR(
        optimizer,
        max_lr=config.learning_rate,
        epochs=config.num_epochs,
        steps_per_epoch=len(train_loader),
        pct_start=config.warmup_epochs / config.num_epochs,
        anneal_strategy='cos',
        final_div_factor=1e3
    )
    
    # Initialize loss function
    criterion = nn.MSELoss()
    
    logger.info(f"Data loaded successfully. Device: {config.device}")
    logger.info(f"Model initialized with {sum(p.numel() for p in model.parameters())} parameters")
    logger.info(f"Training batches: {len(train_loader)}")
    logger.info(f"Validation batches: {len(valid_loader)}")
    logger.info(f"Test batches: {len(test_loader)}")

except Exception as e:
    logger.error(f"Error during initialization: {str(e)}")
    raise
# Out:
# INFO:__main__:Reshaped train tensor: torch.Size([435, 1, 1, 2])
# INFO:__main__:Model Configuration:
# INFO:__main__:input_size: 1
# INFO:__main__:output_size: 1
# INFO:__main__:hidden_size: 256
# INFO:__main__:num_layers: 4
# INFO:__main__:num_heads: 4
# INFO:__main__:bidirectional: True
# INFO:__main__:attention_dropout: 0.1
# INFO:__main__:residual_dropout: 0.2
# INFO:__main__:layer_norm_eps: 1e-05
# INFO:__main__:batch_size: 8
# INFO:__main__:dropout: 0.3
# INFO:__main__:learning_rate: 0.0001
# INFO:__main__:weight_decay: 1e-05
# INFO:__main__:gradient_clip: 1.0
# INFO:__main__:num_epochs: 50
# INFO:__main__:warmup_epochs: 5
# INFO:__main__:lr_schedule: cosine
# INFO:__main__:min_lr: 1e-06
# INFO:__main__:lr_decay_rate: 0.1
# INFO:__main__:lr_patience: 5
# INFO:__main__:early_stopping_patience: 10
# INFO:__main__:early_stopping_min_delta: 0.0001
# INFO:__main__:diversity_alpha: 0.1
# INFO:__main__:consistency_beta: 0.05
# INFO:__main__:mixed_precision: True
# INFO:__main__:num_workers: 0
# INFO:__main__:pin_memory: True
# INFO:__main__:log_interval: 100
# INFO:__main__:checkpoint_interval: 1
# INFO:__main__:Data loaded successfully. Device: cuda
# INFO:__main__:Model initialized with 990853 parameters
# INFO:__main__:Training batches: 55
# INFO:__main__:Validation batches: 18
# INFO:__main__:Test batches: 1

# %%
def train_model(
    model: nn.Module,
    train_loader: DataLoader,
    valid_loader: DataLoader,
    config: Config,
    optimizer: optim.Optimizer,
    scheduler: optim.lr_scheduler._LRScheduler,
    criterion: nn.Module,
    checkpoint_dir: str = './checkpoints'
) -> dict:
    """Train LSTM model with advanced optimizations and monitoring."""
    import os
    def track_gradients():
        total_norm = 0
        for p in model.parameters():
            if p.grad is not None:
                param_norm = p.grad.data.norm(2)
                total_norm += param_norm.item() ** 2
        total_norm = total_norm ** (1/2)
        return total_norm

    def validate_batch(data, targets):
        """Validate input and target data"""
        checks = {
            "Input contains NaN": torch.isnan(data).any(),
            "Input contains inf": torch.isinf(data).any(),
            "Targets contain NaN": torch.isnan(targets).any(),
            "Targets contain inf": torch.isinf(targets).any(),
            "Input all zeros": (data == 0).all(),
            "Input too large": (data.abs() > 1e6).any(),
        }
        
        for message, condition in checks.items():
            if condition:
                logger.error(f"Data validation failed: {message}")
                return False
        return True


        
    logger.info(f"Starting training on device: {config.device}")
    model = model.to(config.device)

    
    # Mixed precision training
    scaler = torch.cuda.amp.GradScaler(enabled=config.mixed_precision)
    
    # Training state tracking
    best_val_loss = float('inf')
    early_stopping_counter = 0
    train_metrics = {
        'train_losses': [],
        'val_losses': [],
        'learning_rates': [],
        'best_epoch': 0
    }
    
    # Create checkpoint directory
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    for epoch in range(config.num_epochs):
        model.train()
        epoch_loss = 0.0
        
        with tqdm(train_loader, desc=f'Epoch {epoch+1}/{config.num_epochs}') as pbar:
            for batch_idx, (data, masks, targets) in enumerate(pbar):
                try:
                    # Move data to device
                    data = data.squeeze(1).to(config.device)  # Remove the extra dimension
                    masks = masks.to(config.device)
                    targets = targets.to(config.device)
                    
                    # Calculate sequence lengths from masks
                    lengths = masks.sum(1).clamp(min=1)
                    
                    # Debug info
                    if batch_idx == 0 and epoch == 0:
                        logger.info(f"Reshaped batch shapes - Data: {data.shape}, Masks: {masks.shape}, "
                                  f"Targets: {targets.shape}, Lengths: {lengths.shape}")
                    
                    
                    # Forward pass with mixed precision
                    with torch.cuda.amp.autocast(enabled=config.mixed_precision):
                        outputs = model(data, lengths)
                        if batch_idx == 0 and epoch == 0:
                            logger.info(f"Output shape: {outputs.shape}")
                        loss = criterion(outputs, targets)
                    if torch.isnan(loss):
                        logger.error(f"""
                        NaN Loss detected:
                        Input stats: min={data.min():.4f}, max={data.max():.4f}, mean={data.mean():.4f}
                        Target stats: min={targets.min():.4f}, max={targets.max():.4f}, mean={targets.mean():.4f}
                        Model output stats: min={outputs.min():.4f}, max={outputs.max():.4f}, mean={outputs.mean():.4f}
                        """)
                        raise ValueError("NaN loss detected")
                    # Backward pass with gradient scaling
                    optimizer.zero_grad(set_to_none=True)
                    scaler.scale(loss).backward()
                    grad_norm = track_gradients()
                    logger.info(f"Gradient norm: {grad_norm:.4f}")
                    # Gradient clipping
                    scaler.unscale_(optimizer)
                    torch.nn.utils.clip_grad_norm_(model.parameters(), config.gradient_clip)
                    
                    # Optimizer step with scaler
                    scaler.step(optimizer)
                    scaler.update()
                    scheduler.step()
                    
                    # Update metrics
                    epoch_loss += loss.item()
                    current_lr = scheduler.get_last_lr()[0]
                    
                    # Update progress bar
                    pbar.set_postfix({
                        'loss': f'{loss.item():.3f}',
                        'lr': f'{current_lr:.2e}'
                    })
                    
                except RuntimeError as e:
                    logger.error(f"Error in batch {batch_idx}: {str(e)}")
                    logger.error(f"Data shapes - Input: {data.shape}, Mask: {masks.shape}, "
                               f"Target: {targets.shape}, Lengths: {lengths.shape}")
                    raise
        
        # Validation phase
        model.eval()
        val_loss = 0.0
        
        with torch.no_grad():
            for data, masks, targets in valid_loader:
                try:
                    data = data.squeeze(1).to(config.device)  # Remove the extra dimension
                    masks = masks.to(config.device)
                    targets = targets.to(config.device)
                    lengths = masks.sum(1).clamp(min=1)
                    
                    with torch.cuda.amp.autocast(enabled=config.mixed_precision):
                        outputs = model(data, lengths)
                        loss = criterion(outputs, targets)
                        val_loss += loss.item()
                        
                except RuntimeError as e:
                    logger.error(f"Error in validation: {str(e)}")
                    raise
        
        # Calculate epoch metrics
        epoch_loss /= len(train_loader)
        val_loss /= len(valid_loader)
        
        # Update training metrics
        train_metrics['train_losses'].append(epoch_loss)
        train_metrics['val_losses'].append(val_loss)
        train_metrics['learning_rates'].append(current_lr)
        
        # Model checkpointing
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            train_metrics['best_epoch'] = epoch
            early_stopping_counter = 0
            
            # Save checkpoint
            checkpoint_path = os.path.join(checkpoint_dir, 'milb_batter_model.pth')
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'scheduler_state_dict': scheduler.state_dict(),
                'val_loss': val_loss,
                'config': asdict(config),
                'metrics': train_metrics,
                'scaler_state_dict': scaler.state_dict()
            }, checkpoint_path)
            
            logger.info(f'New best model saved with validation loss: {val_loss:.4f}')
        else:
            early_stopping_counter += 1
        
        # Log epoch metrics
        logger.info(
            f'Epoch {epoch+1}: '
            f'Train Loss = {epoch_loss:.4f}, '
            f'Val Loss = {val_loss:.4f}, '
            f'LR = {current_lr:.2e}'
        )
        
        # Early stopping check
        if early_stopping_counter >= config.early_stopping_patience:
            logger.info(f'Early stopping triggered after {epoch+1} epochs')
            break
    
    return train_metrics

# Initialize training
try:
    metrics = train_model(
        model=model,
        train_loader=train_loader,
        valid_loader=valid_loader,
        config=config,
        optimizer=optimizer,
        scheduler=scheduler,
        criterion=criterion
    )
except Exception as e:
    logger.error(f"Training failed: {str(e)}")
    raise
# Out:
# INFO:__main__:Starting training on device: cuda
# C:\Users\User\AppData\Local\Temp\ipykernel_29756\2222134134.py:46: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=config.mixed_precision)
# Epoch 1/50:   0%|          | 0/55 [00:00<?, ?it/s]INFO:__main__:Reshaped batch shapes - Data: torch.Size([8, 1, 2]), Masks: torch.Size([8, 1]), Targets: torch.Size([8, 1]), Lengths: torch.Size([8])
# C:\Users\User\AppData\Local\Temp\ipykernel_29756\2222134134.py:83: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=config.mixed_precision):
# INFO:__main__:Output shape: torch.Size([8, 1])
# INFO:__main__:Gradient norm: inf
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 1/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.110, lr=4.00e-06]INFO:__main__:Gradient norm: 248469.8945
# Epoch 1/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.156, lr=4.01e-06]INFO:__main__:Gradient norm: 495183.6407
# Epoch 1/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.396, lr=4.03e-06]INFO:__main__:Gradient norm: 355288.4625
# Epoch 1/50:   7%|▋         | 4/55 [00:00<00:01, 33.06it/s, loss=0.181, lr=4.05e-06]INFO:__main__:Gradient norm: inf
# Epoch 1/50:   7%|▋         | 4/55 [00:00<00:01, 33.06it/s, loss=0.453, lr=4.08e-06]INFO:__main__:Gradient norm: 157503.4556
# Epoch 1/50:   7%|▋         | 4/55 [00:00<00:01, 33.06it/s, loss=0.137, lr=4.11e-06]INFO:__main__:Gradient norm: 86415.3050
# Epoch 1/50:   7%|▋         | 4/55 [00:00<00:01, 33.06it/s, loss=0.057, lr=4.15e-06]INFO:__main__:Gradient norm: 102016.0493
# Epoch 1/50:  15%|█▍        | 8/55 [00:00<00:01, 34.05it/s, loss=0.072, lr=4.20e-06]INFO:__main__:Gradient norm: 220134.2934
# Epoch 1/50:  15%|█▍        | 8/55 [00:00<00:01, 34.05it/s, loss=0.201, lr=4.26e-06]INFO:__main__:Gradient norm: 195638.9618
# Epoch 1/50:  15%|█▍        | 8/55 [00:00<00:01, 34.05it/s, loss=0.195, lr=4.32e-06]INFO:__main__:Gradient norm: 197401.2078
# Epoch 1/50:  15%|█▍        | 8/55 [00:00<00:01, 34.05it/s, loss=0.194, lr=4.38e-06]INFO:__main__:Gradient norm: 242323.1442
# Epoch 1/50:  22%|██▏       | 12/55 [00:00<00:01, 33.33it/s, loss=0.277, lr=4.45e-06]INFO:__main__:Gradient norm: 123696.0307
# Epoch 1/50:  22%|██▏       | 12/55 [00:00<00:01, 33.33it/s, loss=0.166, lr=4.53e-06]INFO:__main__:Gradient norm: 120016.2426
# Epoch 1/50:  22%|██▏       | 12/55 [00:00<00:01, 33.33it/s, loss=0.133, lr=4.62e-06]INFO:__main__:Gradient norm: 156345.6388
# Epoch 1/50:  22%|██▏       | 12/55 [00:00<00:01, 33.33it/s, loss=0.249, lr=4.71e-06]INFO:__main__:Gradient norm: 90053.5791
# Epoch 1/50:  29%|██▉       | 16/55 [00:00<00:01, 33.67it/s, loss=0.051, lr=4.81e-06]INFO:__main__:Gradient norm: 135958.3681
# Epoch 1/50:  29%|██▉       | 16/55 [00:00<00:01, 33.67it/s, loss=0.102, lr=4.91e-06]INFO:__main__:Gradient norm: 120676.5954
# Epoch 1/50:  29%|██▉       | 16/55 [00:00<00:01, 33.67it/s, loss=0.126, lr=5.02e-06]INFO:__main__:Gradient norm: 107636.0702
# Epoch 1/50:  29%|██▉       | 16/55 [00:00<00:01, 33.67it/s, loss=0.107, lr=5.13e-06]INFO:__main__:Gradient norm: 160654.4805
# Epoch 1/50:  36%|███▋      | 20/55 [00:00<00:01, 32.56it/s, loss=0.296, lr=5.26e-06]INFO:__main__:Gradient norm: 145965.7005
# Epoch 1/50:  36%|███▋      | 20/55 [00:00<00:01, 32.56it/s, loss=0.135, lr=5.38e-06]INFO:__main__:Gradient norm: 55639.2749
# Epoch 1/50:  36%|███▋      | 20/55 [00:00<00:01, 32.56it/s, loss=0.093, lr=5.52e-06]INFO:__main__:Gradient norm: 92205.7884
# Epoch 1/50:  36%|███▋      | 20/55 [00:00<00:01, 32.56it/s, loss=0.193, lr=5.66e-06]INFO:__main__:Gradient norm: 154595.7599
# Epoch 1/50:  44%|████▎     | 24/55 [00:00<00:01, 28.52it/s, loss=0.199, lr=5.81e-06]INFO:__main__:Gradient norm: 75041.2734
# Epoch 1/50:  44%|████▎     | 24/55 [00:00<00:01, 28.52it/s, loss=0.046, lr=5.96e-06]INFO:__main__:Gradient norm: 37461.9872
# Epoch 1/50:  44%|████▎     | 24/55 [00:00<00:01, 28.52it/s, loss=0.032, lr=6.12e-06]INFO:__main__:Gradient norm: 85485.8076
# Epoch 1/50:  49%|████▉     | 27/55 [00:00<00:01, 24.65it/s, loss=0.063, lr=6.28e-06]INFO:__main__:Gradient norm: 48337.3766
# Epoch 1/50:  49%|████▉     | 27/55 [00:01<00:01, 24.65it/s, loss=0.055, lr=6.45e-06]INFO:__main__:Gradient norm: 51452.0015
# Epoch 1/50:  49%|████▉     | 27/55 [00:01<00:01, 24.65it/s, loss=0.049, lr=6.63e-06]INFO:__main__:Gradient norm: 67460.8983
# Epoch 1/50:  55%|█████▍    | 30/55 [00:01<00:01, 22.87it/s, loss=0.030, lr=6.81e-06]INFO:__main__:Gradient norm: 72088.1909
# Epoch 1/50:  55%|█████▍    | 30/55 [00:01<00:01, 22.87it/s, loss=0.139, lr=7.00e-06]INFO:__main__:Gradient norm: 79064.3371
# Epoch 1/50:  55%|█████▍    | 30/55 [00:01<00:01, 22.87it/s, loss=0.142, lr=7.19e-06]INFO:__main__:Gradient norm: 78968.7289
# Epoch 1/50:  60%|██████    | 33/55 [00:01<00:00, 22.73it/s, loss=0.164, lr=7.40e-06]INFO:__main__:Gradient norm: 79629.9247
# Epoch 1/50:  60%|██████    | 33/55 [00:01<00:00, 22.73it/s, loss=0.070, lr=7.60e-06]INFO:__main__:Gradient norm: 82899.3150
# Epoch 1/50:  60%|██████    | 33/55 [00:01<00:00, 22.73it/s, loss=0.065, lr=7.81e-06]INFO:__main__:Gradient norm: 40851.0129
# Epoch 1/50:  65%|██████▌   | 36/55 [00:01<00:00, 22.34it/s, loss=0.033, lr=8.03e-06]INFO:__main__:Gradient norm: 77752.4706
# Epoch 1/50:  65%|██████▌   | 36/55 [00:01<00:00, 22.34it/s, loss=0.064, lr=8.25e-06]INFO:__main__:Gradient norm: 50512.8688
# Epoch 1/50:  65%|██████▌   | 36/55 [00:01<00:00, 22.34it/s, loss=0.070, lr=8.48e-06]INFO:__main__:Gradient norm: 50158.9702
# Epoch 1/50:  71%|███████   | 39/55 [00:01<00:00, 23.69it/s, loss=0.061, lr=8.72e-06]INFO:__main__:Gradient norm: 68366.8468
# Epoch 1/50:  71%|███████   | 39/55 [00:01<00:00, 23.69it/s, loss=0.081, lr=8.96e-06]INFO:__main__:Gradient norm: 61168.2732
# Epoch 1/50:  71%|███████   | 39/55 [00:01<00:00, 23.69it/s, loss=0.088, lr=9.21e-06]INFO:__main__:Gradient norm: 69459.0219
# Epoch 1/50:  71%|███████   | 39/55 [00:01<00:00, 23.69it/s, loss=0.029, lr=9.46e-06]INFO:__main__:Gradient norm: 57568.9282
# Epoch 1/50:  78%|███████▊  | 43/55 [00:01<00:00, 26.74it/s, loss=0.067, lr=9.72e-06]INFO:__main__:Gradient norm: 48435.9933
# Epoch 1/50:  78%|███████▊  | 43/55 [00:01<00:00, 26.74it/s, loss=0.053, lr=9.98e-06]INFO:__main__:Gradient norm: 62093.3256
# Epoch 1/50:  78%|███████▊  | 43/55 [00:01<00:00, 26.74it/s, loss=0.089, lr=1.02e-05]INFO:__main__:Gradient norm: 54743.2822
# Epoch 1/50:  78%|███████▊  | 43/55 [00:01<00:00, 26.74it/s, loss=0.076, lr=1.05e-05]INFO:__main__:Gradient norm: 96088.7068
# Epoch 1/50:  85%|████████▌ | 47/55 [00:01<00:00, 27.58it/s, loss=0.086, lr=1.08e-05]INFO:__main__:Gradient norm: 81757.6604
# Epoch 1/50:  85%|████████▌ | 47/55 [00:01<00:00, 27.58it/s, loss=0.120, lr=1.11e-05]INFO:__main__:Gradient norm: 35842.7088
# Epoch 1/50:  85%|████████▌ | 47/55 [00:01<00:00, 27.58it/s, loss=0.038, lr=1.14e-05]INFO:__main__:Gradient norm: 57240.7114
# Epoch 1/50:  91%|█████████ | 50/55 [00:01<00:00, 27.10it/s, loss=0.059, lr=1.17e-05]INFO:__main__:Gradient norm: 34156.1927
# Epoch 1/50:  91%|█████████ | 50/55 [00:01<00:00, 27.10it/s, loss=0.019, lr=1.20e-05]INFO:__main__:Gradient norm: 76283.2904
# Epoch 1/50:  91%|█████████ | 50/55 [00:01<00:00, 27.10it/s, loss=0.119, lr=1.23e-05]INFO:__main__:Gradient norm: 63170.7430
# Epoch 1/50:  96%|█████████▋| 53/55 [00:01<00:00, 27.35it/s, loss=0.062, lr=1.26e-05]INFO:__main__:Gradient norm: 64545.3477
# Epoch 1/50:  96%|█████████▋| 53/55 [00:01<00:00, 27.35it/s, loss=0.078, lr=1.29e-05]INFO:__main__:Gradient norm: 185189.6657
# Epoch 1/50: 100%|██████████| 55/55 [00:02<00:00, 26.91it/s, loss=0.111, lr=1.32e-05]
# C:\Users\User\AppData\Local\Temp\ipykernel_29756\2222134134.py:138: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=config.mixed_precision):
# INFO:__main__:New best model saved with validation loss: 0.0249
# INFO:__main__:Epoch 1: Train Loss = 0.1188, Val Loss = 0.0249, LR = 1.32e-05
# Epoch 2/50:   0%|          | 0/55 [00:00<?, ?it/s]INFO:__main__:Gradient norm: 43776.5884
# Epoch 2/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.051, lr=1.36e-05]INFO:__main__:Gradient norm: 65974.0281
# Epoch 2/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.056, lr=1.39e-05]INFO:__main__:Gradient norm: 55530.9667
# Epoch 2/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.057, lr=1.42e-05]INFO:__main__:Gradient norm: 25088.2618
# Epoch 2/50:   7%|▋         | 4/55 [00:00<00:01, 30.53it/s, loss=0.019, lr=1.46e-05]INFO:__main__:Gradient norm: 104568.5960
# Epoch 2/50:   7%|▋         | 4/55 [00:00<00:01, 30.53it/s, loss=0.078, lr=1.49e-05]INFO:__main__:Gradient norm: 75509.3588
# Epoch 2/50:   7%|▋         | 4/55 [00:00<00:01, 30.53it/s, loss=0.102, lr=1.53e-05]INFO:__main__:Gradient norm: 64329.0989
# Epoch 2/50:   7%|▋         | 4/55 [00:00<00:01, 30.53it/s, loss=0.084, lr=1.56e-05]INFO:__main__:Gradient norm: 86835.3936
# Epoch 2/50:  15%|█▍        | 8/55 [00:00<00:01, 31.09it/s, loss=0.059, lr=1.60e-05]INFO:__main__:Gradient norm: 127513.9180
# Epoch 2/50:  15%|█▍        | 8/55 [00:00<00:01, 31.09it/s, loss=0.103, lr=1.64e-05]INFO:__main__:Gradient norm: 76344.1554
# Epoch 2/50:  15%|█▍        | 8/55 [00:00<00:01, 31.09it/s, loss=0.056, lr=1.67e-05]INFO:__main__:Gradient norm: 47751.9188
# Epoch 2/50:  15%|█▍        | 8/55 [00:00<00:01, 31.09it/s, loss=0.026, lr=1.71e-05]INFO:__main__:Gradient norm: 43806.0226
# Epoch 2/50:  22%|██▏       | 12/55 [00:00<00:01, 28.80it/s, loss=0.056, lr=1.75e-05]INFO:__main__:Gradient norm: 48515.9824
# Epoch 2/50:  22%|██▏       | 12/55 [00:00<00:01, 28.80it/s, loss=0.058, lr=1.79e-05]INFO:__main__:Gradient norm: 76585.3011
# Epoch 2/50:  22%|██▏       | 12/55 [00:00<00:01, 28.80it/s, loss=0.081, lr=1.83e-05]INFO:__main__:Gradient norm: 89831.6972
# Epoch 2/50:  27%|██▋       | 15/55 [00:00<00:01, 28.73it/s, loss=0.102, lr=1.86e-05]INFO:__main__:Gradient norm: 66043.1468
# Epoch 2/50:  27%|██▋       | 15/55 [00:00<00:01, 28.73it/s, loss=0.118, lr=1.90e-05]INFO:__main__:Gradient norm: 45856.8920
# Epoch 2/50:  27%|██▋       | 15/55 [00:00<00:01, 28.73it/s, loss=0.071, lr=1.94e-05]INFO:__main__:Gradient norm: 80539.9919
# Epoch 2/50:  27%|██▋       | 15/55 [00:00<00:01, 28.73it/s, loss=0.073, lr=1.99e-05]INFO:__main__:Gradient norm: 86022.3022
# Epoch 2/50:  35%|███▍      | 19/55 [00:00<00:01, 30.08it/s, loss=0.142, lr=2.03e-05]INFO:__main__:Gradient norm: 34528.3579
# Epoch 2/50:  35%|███▍      | 19/55 [00:00<00:01, 30.08it/s, loss=0.045, lr=2.07e-05]INFO:__main__:Gradient norm: 71957.3968
# Epoch 2/50:  35%|███▍      | 19/55 [00:00<00:01, 30.08it/s, loss=0.102, lr=2.11e-05]INFO:__main__:Gradient norm: 36014.1758
# Epoch 2/50:  35%|███▍      | 19/55 [00:00<00:01, 30.08it/s, loss=0.013, lr=2.15e-05]INFO:__main__:Gradient norm: 34452.9971
# Epoch 2/50:  42%|████▏     | 23/55 [00:00<00:01, 29.22it/s, loss=0.031, lr=2.19e-05]INFO:__main__:Gradient norm: 41142.6167
# Epoch 2/50:  42%|████▏     | 23/55 [00:00<00:01, 29.22it/s, loss=0.039, lr=2.24e-05]INFO:__main__:Gradient norm: 58173.3078
# Epoch 2/50:  42%|████▏     | 23/55 [00:00<00:01, 29.22it/s, loss=0.051, lr=2.28e-05]INFO:__main__:Gradient norm: 45209.0383
# Epoch 2/50:  42%|████▏     | 23/55 [00:00<00:01, 29.22it/s, loss=0.046, lr=2.33e-05]INFO:__main__:Gradient norm: 97256.4685
# Epoch 2/50:  49%|████▉     | 27/55 [00:00<00:00, 29.80it/s, loss=0.091, lr=2.37e-05]INFO:__main__:Gradient norm: 74014.5380
# Epoch 2/50:  49%|████▉     | 27/55 [00:00<00:00, 29.80it/s, loss=0.162, lr=2.41e-05]INFO:__main__:Gradient norm: 52495.8645
# Epoch 2/50:  49%|████▉     | 27/55 [00:00<00:00, 29.80it/s, loss=0.023, lr=2.46e-05]INFO:__main__:Gradient norm: 88910.4116
# Epoch 2/50:  49%|████▉     | 27/55 [00:01<00:00, 29.80it/s, loss=0.063, lr=2.50e-05]INFO:__main__:Gradient norm: 66285.9510
# Epoch 2/50:  56%|█████▋    | 31/55 [00:01<00:00, 29.67it/s, loss=0.100, lr=2.55e-05]INFO:__main__:Gradient norm: 59346.9480
# Epoch 2/50:  56%|█████▋    | 31/55 [00:01<00:00, 29.67it/s, loss=0.096, lr=2.60e-05]INFO:__main__:Gradient norm: 72506.7011
# Epoch 2/50:  56%|█████▋    | 31/55 [00:01<00:00, 29.67it/s, loss=0.033, lr=2.64e-05]INFO:__main__:Gradient norm: 46905.9494
# Epoch 2/50:  62%|██████▏   | 34/55 [00:01<00:00, 26.87it/s, loss=0.037, lr=2.69e-05]INFO:__main__:Gradient norm: 31755.7041
# Epoch 2/50:  62%|██████▏   | 34/55 [00:01<00:00, 26.87it/s, loss=0.036, lr=2.74e-05]INFO:__main__:Gradient norm: 56100.8414
# Epoch 2/50:  62%|██████▏   | 34/55 [00:01<00:00, 26.87it/s, loss=0.041, lr=2.78e-05]INFO:__main__:Gradient norm: 73679.3072
# Epoch 2/50:  67%|██████▋   | 37/55 [00:01<00:00, 24.98it/s, loss=0.055, lr=2.83e-05]INFO:__main__:Gradient norm: 62842.7487
# Epoch 2/50:  67%|██████▋   | 37/55 [00:01<00:00, 24.98it/s, loss=0.060, lr=2.88e-05]INFO:__main__:Gradient norm: 33573.0335
# Epoch 2/50:  67%|██████▋   | 37/55 [00:01<00:00, 24.98it/s, loss=0.026, lr=2.93e-05]INFO:__main__:Gradient norm: 53112.6916
# Epoch 2/50:  73%|███████▎  | 40/55 [00:01<00:00, 23.16it/s, loss=0.045, lr=2.98e-05]INFO:__main__:Gradient norm: 85102.8129
# Epoch 2/50:  73%|███████▎  | 40/55 [00:01<00:00, 23.16it/s, loss=0.063, lr=3.03e-05]INFO:__main__:Gradient norm: 39533.3285
# Epoch 2/50:  73%|███████▎  | 40/55 [00:01<00:00, 23.16it/s, loss=0.026, lr=3.07e-05]INFO:__main__:Gradient norm: 92427.9921
# Epoch 2/50:  78%|███████▊  | 43/55 [00:01<00:00, 22.35it/s, loss=0.062, lr=3.12e-05]INFO:__main__:Gradient norm: 55029.9353
# Epoch 2/50:  78%|███████▊  | 43/55 [00:01<00:00, 22.35it/s, loss=0.056, lr=3.17e-05]INFO:__main__:Gradient norm: 42915.7274
# Epoch 2/50:  78%|███████▊  | 43/55 [00:01<00:00, 22.35it/s, loss=0.064, lr=3.22e-05]INFO:__main__:Gradient norm: 46933.9731
# Epoch 2/50:  84%|████████▎ | 46/55 [00:01<00:00, 24.02it/s, loss=0.089, lr=3.27e-05]INFO:__main__:Gradient norm: 75026.7602
# Epoch 2/50:  84%|████████▎ | 46/55 [00:01<00:00, 24.02it/s, loss=0.109, lr=3.33e-05]INFO:__main__:Gradient norm: 43921.3474
# Epoch 2/50:  84%|████████▎ | 46/55 [00:01<00:00, 24.02it/s, loss=0.042, lr=3.38e-05]INFO:__main__:Gradient norm: 56743.8603
# Epoch 2/50:  89%|████████▉ | 49/55 [00:01<00:00, 25.50it/s, loss=0.084, lr=3.43e-05]INFO:__main__:Gradient norm: 52792.0160
# Epoch 2/50:  89%|████████▉ | 49/55 [00:01<00:00, 25.50it/s, loss=0.046, lr=3.48e-05]INFO:__main__:Gradient norm: 17034.5743
# Epoch 2/50:  89%|████████▉ | 49/55 [00:01<00:00, 25.50it/s, loss=0.012, lr=3.53e-05]INFO:__main__:Gradient norm: 29137.8679
# Epoch 2/50:  95%|█████████▍| 52/55 [00:01<00:00, 25.74it/s, loss=0.035, lr=3.58e-05]INFO:__main__:Gradient norm: 78544.5925
# Epoch 2/50:  95%|█████████▍| 52/55 [00:01<00:00, 25.74it/s, loss=0.072, lr=3.63e-05]INFO:__main__:Gradient norm: 58414.5096
# Epoch 2/50:  95%|█████████▍| 52/55 [00:02<00:00, 25.74it/s, loss=0.032, lr=3.69e-05]INFO:__main__:Gradient norm: 101525.5475
# Epoch 2/50: 100%|██████████| 55/55 [00:02<00:00, 26.13it/s, loss=0.062, lr=3.74e-05]
# INFO:__main__:Epoch 2: Train Loss = 0.0625, Val Loss = 0.0264, LR = 3.74e-05
# Epoch 3/50:   0%|          | 0/55 [00:00<?, ?it/s]INFO:__main__:Gradient norm: 49004.9789
# Epoch 3/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.055, lr=3.79e-05]INFO:__main__:Gradient norm: 22767.4829
# Epoch 3/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.021, lr=3.84e-05]INFO:__main__:Gradient norm: 51323.0097
# Epoch 3/50:   5%|▌         | 3/55 [00:00<00:01, 26.79it/s, loss=0.028, lr=3.90e-05]INFO:__main__:Gradient norm: 36708.4450
# Epoch 3/50:   5%|▌         | 3/55 [00:00<00:01, 26.79it/s, loss=0.022, lr=3.95e-05]INFO:__main__:Gradient norm: 32546.2745
# Epoch 3/50:   5%|▌         | 3/55 [00:00<00:01, 26.79it/s, loss=0.035, lr=4.00e-05]INFO:__main__:Gradient norm: 40629.7561
# Epoch 3/50:  11%|█         | 6/55 [00:00<00:01, 25.76it/s, loss=0.049, lr=4.06e-05]INFO:__main__:Gradient norm: 38106.9271
# Epoch 3/50:  11%|█         | 6/55 [00:00<00:01, 25.76it/s, loss=0.049, lr=4.11e-05]INFO:__main__:Gradient norm: 23099.6931
# Epoch 3/50:  11%|█         | 6/55 [00:00<00:01, 25.76it/s, loss=0.025, lr=4.16e-05]INFO:__main__:Gradient norm: 73406.9128
# Epoch 3/50:  16%|█▋        | 9/55 [00:00<00:01, 26.43it/s, loss=0.085, lr=4.22e-05]INFO:__main__:Gradient norm: 58930.0036
# Epoch 3/50:  16%|█▋        | 9/55 [00:00<00:01, 26.43it/s, loss=0.067, lr=4.27e-05]INFO:__main__:Gradient norm: 20559.2875
# Epoch 3/50:  16%|█▋        | 9/55 [00:00<00:01, 26.43it/s, loss=0.013, lr=4.32e-05]INFO:__main__:Gradient norm: 94945.7167
# Epoch 3/50:  22%|██▏       | 12/55 [00:00<00:01, 26.38it/s, loss=0.058, lr=4.38e-05]INFO:__main__:Gradient norm: 62533.4025
# Epoch 3/50:  22%|██▏       | 12/55 [00:00<00:01, 26.38it/s, loss=0.041, lr=4.43e-05]INFO:__main__:Gradient norm: 44753.4476
# Epoch 3/50:  22%|██▏       | 12/55 [00:00<00:01, 26.38it/s, loss=0.042, lr=4.49e-05]INFO:__main__:Gradient norm: 49474.0600
# Epoch 3/50:  22%|██▏       | 12/55 [00:00<00:01, 26.38it/s, loss=0.071, lr=4.54e-05]INFO:__main__:Gradient norm: 59390.0072
# Epoch 3/50:  29%|██▉       | 16/55 [00:00<00:01, 28.19it/s, loss=0.067, lr=4.60e-05]INFO:__main__:Gradient norm: 29660.3073
# Epoch 3/50:  29%|██▉       | 16/55 [00:00<00:01, 28.19it/s, loss=0.026, lr=4.65e-05]INFO:__main__:Gradient norm: 42428.4370
# Epoch 3/50:  29%|██▉       | 16/55 [00:00<00:01, 28.19it/s, loss=0.037, lr=4.71e-05]INFO:__main__:Gradient norm: 44426.7088
# Epoch 3/50:  35%|███▍      | 19/55 [00:00<00:01, 28.39it/s, loss=0.091, lr=4.76e-05]INFO:__main__:Gradient norm: 31637.6424
# Epoch 3/50:  35%|███▍      | 19/55 [00:00<00:01, 28.39it/s, loss=0.014, lr=4.82e-05]INFO:__main__:Gradient norm: 42280.4461
# Epoch 3/50:  35%|███▍      | 19/55 [00:00<00:01, 28.39it/s, loss=0.049, lr=4.87e-05]INFO:__main__:Gradient norm: 67637.3737
# Epoch 3/50:  40%|████      | 22/55 [00:00<00:01, 28.04it/s, loss=0.032, lr=4.92e-05]INFO:__main__:Gradient norm: 28199.0731
# Epoch 3/50:  40%|████      | 22/55 [00:00<00:01, 28.04it/s, loss=0.026, lr=4.98e-05]INFO:__main__:Gradient norm: 33350.1421
# Epoch 3/50:  40%|████      | 22/55 [00:00<00:01, 28.04it/s, loss=0.015, lr=5.03e-05]INFO:__main__:Gradient norm: 52490.0278
# Epoch 3/50:  45%|████▌     | 25/55 [00:00<00:01, 28.44it/s, loss=0.029, lr=5.09e-05]INFO:__main__:Gradient norm: 74684.0632
# Epoch 3/50:  45%|████▌     | 25/55 [00:00<00:01, 28.44it/s, loss=0.115, lr=5.14e-05]INFO:__main__:Gradient norm: 50668.6982
# Epoch 3/50:  45%|████▌     | 25/55 [00:00<00:01, 28.44it/s, loss=0.076, lr=5.20e-05]INFO:__main__:Gradient norm: 31592.8542
# Epoch 3/50:  45%|████▌     | 25/55 [00:00<00:01, 28.44it/s, loss=0.028, lr=5.26e-05]INFO:__main__:Gradient norm: 27678.3354
# Epoch 3/50:  53%|█████▎    | 29/55 [00:01<00:00, 29.26it/s, loss=0.034, lr=5.31e-05]INFO:__main__:Gradient norm: 63291.0899
# Epoch 3/50:  53%|█████▎    | 29/55 [00:01<00:00, 29.26it/s, loss=0.064, lr=5.37e-05]INFO:__main__:Gradient norm: 32942.9940
# Epoch 3/50:  53%|█████▎    | 29/55 [00:01<00:00, 29.26it/s, loss=0.057, lr=5.42e-05]INFO:__main__:Gradient norm: 36765.6513
# Epoch 3/50:  53%|█████▎    | 29/55 [00:01<00:00, 29.26it/s, loss=0.055, lr=5.48e-05]INFO:__main__:Gradient norm: 57110.6632
# Epoch 3/50:  60%|██████    | 33/55 [00:01<00:00, 30.15it/s, loss=0.041, lr=5.53e-05]INFO:__main__:Gradient norm: 41929.2602
# Epoch 3/50:  60%|██████    | 33/55 [00:01<00:00, 30.15it/s, loss=0.048, lr=5.58e-05]INFO:__main__:Gradient norm: 27893.6969
# Epoch 3/50:  60%|██████    | 33/55 [00:01<00:00, 30.15it/s, loss=0.020, lr=5.64e-05]INFO:__main__:Gradient norm: 42089.4508
# Epoch 3/50:  60%|██████    | 33/55 [00:01<00:00, 30.15it/s, loss=0.047, lr=5.69e-05]INFO:__main__:Gradient norm: 69651.3039
# Epoch 3/50:  67%|██████▋   | 37/55 [00:01<00:00, 29.47it/s, loss=0.047, lr=5.75e-05]INFO:__main__:Gradient norm: 48940.9756
# Epoch 3/50:  67%|██████▋   | 37/55 [00:01<00:00, 29.47it/s, loss=0.042, lr=5.80e-05]INFO:__main__:Gradient norm: 82173.8229
# Epoch 3/50:  67%|██████▋   | 37/55 [00:01<00:00, 29.47it/s, loss=0.088, lr=5.86e-05]INFO:__main__:Gradient norm: 51466.3361
# Epoch 3/50:  73%|███████▎  | 40/55 [00:01<00:00, 29.01it/s, loss=0.055, lr=5.91e-05]INFO:__main__:Gradient norm: 42709.9691
# Epoch 3/50:  73%|███████▎  | 40/55 [00:01<00:00, 29.01it/s, loss=0.073, lr=5.97e-05]INFO:__main__:Gradient norm: 55550.6108
# Epoch 3/50:  73%|███████▎  | 40/55 [00:01<00:00, 29.01it/s, loss=0.064, lr=6.02e-05]INFO:__main__:Gradient norm: 70270.4026
# Epoch 3/50:  78%|███████▊  | 43/55 [00:01<00:00, 28.51it/s, loss=0.054, lr=6.08e-05]INFO:__main__:Gradient norm: 59023.7062
# Epoch 3/50:  78%|███████▊  | 43/55 [00:01<00:00, 28.51it/s, loss=0.090, lr=6.13e-05]INFO:__main__:Gradient norm: 22841.2467
# Epoch 3/50:  78%|███████▊  | 43/55 [00:01<00:00, 28.51it/s, loss=0.014, lr=6.18e-05]INFO:__main__:Gradient norm: 36748.8285
# Epoch 3/50:  84%|████████▎ | 46/55 [00:01<00:00, 28.84it/s, loss=0.020, lr=6.24e-05]INFO:__main__:Gradient norm: 33832.5239
# Epoch 3/50:  84%|████████▎ | 46/55 [00:01<00:00, 28.84it/s, loss=0.030, lr=6.29e-05]INFO:__main__:Gradient norm: 9969.7483
# Epoch 3/50:  84%|████████▎ | 46/55 [00:01<00:00, 28.84it/s, loss=0.010, lr=6.34e-05]INFO:__main__:Gradient norm: 23922.7114
# Epoch 3/50:  89%|████████▉ | 49/55 [00:01<00:00, 29.16it/s, loss=0.018, lr=6.40e-05]INFO:__main__:Gradient norm: 26422.6608
# Epoch 3/50:  89%|████████▉ | 49/55 [00:01<00:00, 29.16it/s, loss=0.046, lr=6.45e-05]INFO:__main__:Gradient norm: 21117.3468
# Epoch 3/50:  89%|████████▉ | 49/55 [00:01<00:00, 29.16it/s, loss=0.015, lr=6.50e-05]INFO:__main__:Gradient norm: 25099.3373
# Epoch 3/50:  89%|████████▉ | 49/55 [00:01<00:00, 29.16it/s, loss=0.023, lr=6.56e-05]INFO:__main__:Gradient norm: 30771.8189
# Epoch 3/50:  96%|█████████▋| 53/55 [00:01<00:00, 30.10it/s, loss=0.055, lr=6.61e-05]INFO:__main__:Gradient norm: 47520.3160
# Epoch 3/50:  96%|█████████▋| 53/55 [00:01<00:00, 30.10it/s, loss=0.032, lr=6.66e-05]INFO:__main__:Gradient norm: 84423.4728
# Epoch 3/50: 100%|██████████| 55/55 [00:01<00:00, 28.85it/s, loss=0.071, lr=6.71e-05]
# INFO:__main__:New best model saved with validation loss: 0.0196
# INFO:__main__:Epoch 3: Train Loss = 0.0451, Val Loss = 0.0196, LR = 6.71e-05
# Epoch 4/50:   0%|          | 0/55 [00:00<?, ?it/s]INFO:__main__:Gradient norm: 23101.0369
# Epoch 4/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.022, lr=6.77e-05]INFO:__main__:Gradient norm: 18166.7128
# Epoch 4/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.018, lr=6.82e-05]INFO:__main__:Gradient norm: 18201.5535
# Epoch 4/50:   5%|▌         | 3/55 [00:00<00:01, 30.00it/s, loss=0.013, lr=6.87e-05]INFO:__main__:Gradient norm: 73437.1527
# Epoch 4/50:   5%|▌         | 3/55 [00:00<00:01, 30.00it/s, loss=0.054, lr=6.92e-05]INFO:__main__:Gradient norm: 57427.4022
# Epoch 4/50:   5%|▌         | 3/55 [00:00<00:01, 30.00it/s, loss=0.049, lr=6.97e-05]INFO:__main__:Gradient norm: 17083.7997
# Epoch 4/50:  11%|█         | 6/55 [00:00<00:01, 25.37it/s, loss=0.004, lr=7.02e-05]INFO:__main__:Gradient norm: 44522.5677
# Epoch 4/50:  11%|█         | 6/55 [00:00<00:01, 25.37it/s, loss=0.075, lr=7.07e-05]INFO:__main__:Gradient norm: 30232.5787
# Epoch 4/50:  11%|█         | 6/55 [00:00<00:01, 25.37it/s, loss=0.023, lr=7.13e-05]INFO:__main__:Gradient norm: 24684.7922
# Epoch 4/50:  16%|█▋        | 9/55 [00:00<00:01, 26.21it/s, loss=0.027, lr=7.18e-05]INFO:__main__:Gradient norm: 22354.8089
# Epoch 4/50:  16%|█▋        | 9/55 [00:00<00:01, 26.21it/s, loss=0.033, lr=7.23e-05]INFO:__main__:Gradient norm: 26986.6882
# Epoch 4/50:  16%|█▋        | 9/55 [00:00<00:01, 26.21it/s, loss=0.032, lr=7.28e-05]INFO:__main__:Gradient norm: 46504.1963
# Epoch 4/50:  22%|██▏       | 12/55 [00:00<00:01, 27.48it/s, loss=0.084, lr=7.33e-05]INFO:__main__:Gradient norm: 19221.5944
# Epoch 4/50:  22%|██▏       | 12/55 [00:00<00:01, 27.48it/s, loss=0.017, lr=7.37e-05]INFO:__main__:Gradient norm: 14993.8093
# Epoch 4/50:  22%|██▏       | 12/55 [00:00<00:01, 27.48it/s, loss=0.015, lr=7.42e-05]INFO:__main__:Gradient norm: 25623.2198
# Epoch 4/50:  22%|██▏       | 12/55 [00:00<00:01, 27.48it/s, loss=0.034, lr=7.47e-05]INFO:__main__:Gradient norm: 31041.1835
# Epoch 4/50:  29%|██▉       | 16/55 [00:00<00:01, 29.07it/s, loss=0.062, lr=7.52e-05]INFO:__main__:Gradient norm: 60616.5499
# Epoch 4/50:  29%|██▉       | 16/55 [00:00<00:01, 29.07it/s, loss=0.036, lr=7.57e-05]INFO:__main__:Gradient norm: 20298.0199
# Epoch 4/50:  29%|██▉       | 16/55 [00:00<00:01, 29.07it/s, loss=0.033, lr=7.62e-05]INFO:__main__:Gradient norm: 23874.2087
# Epoch 4/50:  29%|██▉       | 16/55 [00:00<00:01, 29.07it/s, loss=0.038, lr=7.66e-05]INFO:__main__:Gradient norm: 15406.5285
# Epoch 4/50:  36%|███▋      | 20/55 [00:00<00:01, 30.04it/s, loss=0.010, lr=7.71e-05]INFO:__main__:Gradient norm: 22565.2817
# Epoch 4/50:  36%|███▋      | 20/55 [00:00<00:01, 30.04it/s, loss=0.027, lr=7.76e-05]INFO:__main__:Gradient norm: 49514.0266
# Epoch 4/50:  36%|███▋      | 20/55 [00:00<00:01, 30.04it/s, loss=0.026, lr=7.80e-05]INFO:__main__:Gradient norm: 14157.5440
# Epoch 4/50:  36%|███▋      | 20/55 [00:00<00:01, 30.04it/s, loss=0.009, lr=7.85e-05]INFO:__main__:Gradient norm: 30043.6833
# Epoch 4/50:  44%|████▎     | 24/55 [00:00<00:01, 30.70it/s, loss=0.035, lr=7.90e-05]INFO:__main__:Gradient norm: 48213.5733
# Epoch 4/50:  44%|████▎     | 24/55 [00:00<00:01, 30.70it/s, loss=0.043, lr=7.94e-05]INFO:__main__:Gradient norm: 40212.8355
# Epoch 4/50:  44%|████▎     | 24/55 [00:00<00:01, 30.70it/s, loss=0.028, lr=7.99e-05]INFO:__main__:Gradient norm: 39847.7071
# Epoch 4/50:  44%|████▎     | 24/55 [00:00<00:01, 30.70it/s, loss=0.018, lr=8.03e-05]INFO:__main__:Gradient norm: 16812.7143
# Epoch 4/50:  51%|█████     | 28/55 [00:00<00:00, 30.96it/s, loss=0.018, lr=8.07e-05]INFO:__main__:Gradient norm: 26502.2778
# Epoch 4/50:  51%|█████     | 28/55 [00:00<00:00, 30.96it/s, loss=0.033, lr=8.12e-05]INFO:__main__:Gradient norm: 36186.5788
# Epoch 4/50:  51%|█████     | 28/55 [00:01<00:00, 30.96it/s, loss=0.039, lr=8.16e-05]INFO:__main__:Gradient norm: 16205.9378
# Epoch 4/50:  51%|█████     | 28/55 [00:01<00:00, 30.96it/s, loss=0.017, lr=8.21e-05]INFO:__main__:Gradient norm: 36424.9592
# Epoch 4/50:  58%|█████▊    | 32/55 [00:01<00:00, 31.21it/s, loss=0.017, lr=8.25e-05]INFO:__main__:Gradient norm: 52015.7782
# Epoch 4/50:  58%|█████▊    | 32/55 [00:01<00:00, 31.21it/s, loss=0.044, lr=8.29e-05]INFO:__main__:Gradient norm: 46749.8999
# Epoch 4/50:  58%|█████▊    | 32/55 [00:01<00:00, 31.21it/s, loss=0.042, lr=8.33e-05]INFO:__main__:Gradient norm: 19034.5004
# Epoch 4/50:  58%|█████▊    | 32/55 [00:01<00:00, 31.21it/s, loss=0.012, lr=8.37e-05]INFO:__main__:Gradient norm: 11656.8456
# Epoch 4/50:  65%|██████▌   | 36/55 [00:01<00:00, 30.62it/s, loss=0.012, lr=8.41e-05]INFO:__main__:Gradient norm: 18696.0563
# Epoch 4/50:  65%|██████▌   | 36/55 [00:01<00:00, 30.62it/s, loss=0.018, lr=8.46e-05]INFO:__main__:Gradient norm: 38510.0532
# Epoch 4/50:  65%|██████▌   | 36/55 [00:01<00:00, 30.62it/s, loss=0.022, lr=8.50e-05]INFO:__main__:Gradient norm: 39199.0801
# Epoch 4/50:  65%|██████▌   | 36/55 [00:01<00:00, 30.62it/s, loss=0.025, lr=8.54e-05]INFO:__main__:Gradient norm: 25501.4185
# Epoch 4/50:  73%|███████▎  | 40/55 [00:01<00:00, 30.16it/s, loss=0.017, lr=8.57e-05]INFO:__main__:Gradient norm: 17406.4381
# Epoch 4/50:  73%|███████▎  | 40/55 [00:01<00:00, 30.16it/s, loss=0.008, lr=8.61e-05]INFO:__main__:Gradient norm: 16965.9318
# Epoch 4/50:  73%|███████▎  | 40/55 [00:01<00:00, 30.16it/s, loss=0.017, lr=8.65e-05]INFO:__main__:Gradient norm: 28587.8658
# Epoch 4/50:  73%|███████▎  | 40/55 [00:01<00:00, 30.16it/s, loss=0.019, lr=8.69e-05]INFO:__main__:Gradient norm: 30945.7007
# Epoch 4/50:  80%|████████  | 44/55 [00:01<00:00, 30.35it/s, loss=0.046, lr=8.73e-05]INFO:__main__:Gradient norm: 16261.7155
# Epoch 4/50:  80%|████████  | 44/55 [00:01<00:00, 30.35it/s, loss=0.019, lr=8.76e-05]INFO:__main__:Gradient norm: 27554.1229
# Epoch 4/50:  80%|████████  | 44/55 [00:01<00:00, 30.35it/s, loss=0.010, lr=8.80e-05]INFO:__main__:Gradient norm: 89090.8804
# Epoch 4/50:  80%|████████  | 44/55 [00:01<00:00, 30.35it/s, loss=0.094, lr=8.84e-05]INFO:__main__:Gradient norm: 24319.7987
# Epoch 4/50:  87%|████████▋ | 48/55 [00:01<00:00, 30.19it/s, loss=0.022, lr=8.87e-05]INFO:__main__:Gradient norm: 46652.3387
# Epoch 4/50:  87%|████████▋ | 48/55 [00:01<00:00, 30.19it/s, loss=0.052, lr=8.91e-05]INFO:__main__:Gradient norm: 19302.9825
# Epoch 4/50:  87%|████████▋ | 48/55 [00:01<00:00, 30.19it/s, loss=0.020, lr=8.94e-05]INFO:__main__:Gradient norm: 29359.1010
# Epoch 4/50:  87%|████████▋ | 48/55 [00:01<00:00, 30.19it/s, loss=0.033, lr=8.98e-05]INFO:__main__:Gradient norm: 23324.8911
# Epoch 4/50:  95%|█████████▍| 52/55 [00:01<00:00, 30.23it/s, loss=0.031, lr=9.01e-05]INFO:__main__:Gradient norm: 42650.6546
# Epoch 4/50:  95%|█████████▍| 52/55 [00:01<00:00, 30.23it/s, loss=0.061, lr=9.04e-05]INFO:__main__:Gradient norm: 26927.7899
# Epoch 4/50:  95%|█████████▍| 52/55 [00:01<00:00, 30.23it/s, loss=0.039, lr=9.08e-05]INFO:__main__:Gradient norm: 25919.4895
# Epoch 4/50: 100%|██████████| 55/55 [00:01<00:00, 29.86it/s, loss=0.014, lr=9.11e-05]
# INFO:__main__:Epoch 4: Train Loss = 0.0303, Val Loss = 0.0217, LR = 9.11e-05
# Epoch 5/50:   0%|          | 0/55 [00:00<?, ?it/s]INFO:__main__:Gradient norm: 44246.0456
# Epoch 5/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.024, lr=9.14e-05]INFO:__main__:Gradient norm: 44107.3918
# Epoch 5/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.031, lr=9.17e-05]INFO:__main__:Gradient norm: 29015.7729
# Epoch 5/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.014, lr=9.20e-05]INFO:__main__:Gradient norm: 23422.6334
# Epoch 5/50:   7%|▋         | 4/55 [00:00<00:01, 27.40it/s, loss=0.011, lr=9.23e-05]INFO:__main__:Gradient norm: 29206.9581
# Epoch 5/50:   7%|▋         | 4/55 [00:00<00:01, 27.40it/s, loss=0.026, lr=9.26e-05]INFO:__main__:Gradient norm: 16101.1611
# Epoch 5/50:   7%|▋         | 4/55 [00:00<00:01, 27.40it/s, loss=0.017, lr=9.29e-05]INFO:__main__:Gradient norm: 12481.0514
# Epoch 5/50:  13%|█▎        | 7/55 [00:00<00:01, 25.20it/s, loss=0.015, lr=9.32e-05]INFO:__main__:Gradient norm: 12651.9754
# Epoch 5/50:  13%|█▎        | 7/55 [00:00<00:01, 25.20it/s, loss=0.008, lr=9.35e-05]INFO:__main__:Gradient norm: 18570.8243
# Epoch 5/50:  13%|█▎        | 7/55 [00:00<00:01, 25.20it/s, loss=0.024, lr=9.38e-05]INFO:__main__:Gradient norm: 61625.2744
# Epoch 5/50:  13%|█▎        | 7/55 [00:00<00:01, 25.20it/s, loss=0.102, lr=9.40e-05]INFO:__main__:Gradient norm: 20588.0416
# Epoch 5/50:  20%|██        | 11/55 [00:00<00:01, 28.53it/s, loss=0.038, lr=9.43e-05]INFO:__main__:Gradient norm: 12762.2002
# Epoch 5/50:  20%|██        | 11/55 [00:00<00:01, 28.53it/s, loss=0.009, lr=9.45e-05]INFO:__main__:Gradient norm: 20165.6211
# Epoch 5/50:  20%|██        | 11/55 [00:00<00:01, 28.53it/s, loss=0.015, lr=9.48e-05]INFO:__main__:Gradient norm: 47446.2613
# Epoch 5/50:  25%|██▌       | 14/55 [00:00<00:01, 27.11it/s, loss=0.072, lr=9.50e-05]INFO:__main__:Gradient norm: 17938.2239
# Epoch 5/50:  25%|██▌       | 14/55 [00:00<00:01, 27.11it/s, loss=0.019, lr=9.53e-05]INFO:__main__:Gradient norm: 34523.4052
# Epoch 5/50:  25%|██▌       | 14/55 [00:00<00:01, 27.11it/s, loss=0.013, lr=9.55e-05]INFO:__main__:Gradient norm: 31170.0880
# Epoch 5/50:  31%|███       | 17/55 [00:00<00:01, 27.75it/s, loss=0.033, lr=9.57e-05]INFO:__main__:Gradient norm: 18590.6446
# Epoch 5/50:  31%|███       | 17/55 [00:00<00:01, 27.75it/s, loss=0.022, lr=9.60e-05]INFO:__main__:Gradient norm: 14372.4178
# Epoch 5/50:  31%|███       | 17/55 [00:00<00:01, 27.75it/s, loss=0.021, lr=9.62e-05]INFO:__main__:Gradient norm: 45468.9833
# Epoch 5/50:  31%|███       | 17/55 [00:00<00:01, 27.75it/s, loss=0.022, lr=9.64e-05]INFO:__main__:Gradient norm: 13837.0699
# Epoch 5/50:  38%|███▊      | 21/55 [00:00<00:01, 29.34it/s, loss=0.023, lr=9.66e-05]INFO:__main__:Gradient norm: 22275.4178
# Epoch 5/50:  38%|███▊      | 21/55 [00:00<00:01, 29.34it/s, loss=0.035, lr=9.68e-05]INFO:__main__:Gradient norm: 16628.9959
# Epoch 5/50:  38%|███▊      | 21/55 [00:00<00:01, 29.34it/s, loss=0.017, lr=9.70e-05]INFO:__main__:Gradient norm: 23314.0738
# Epoch 5/50:  38%|███▊      | 21/55 [00:00<00:01, 29.34it/s, loss=0.006, lr=9.72e-05]INFO:__main__:Gradient norm: 53212.4203
# Epoch 5/50:  45%|████▌     | 25/55 [00:00<00:00, 30.07it/s, loss=0.034, lr=9.74e-05]INFO:__main__:Gradient norm: 9376.2990
# Epoch 5/50:  45%|████▌     | 25/55 [00:00<00:00, 30.07it/s, loss=0.011, lr=9.75e-05]INFO:__main__:Gradient norm: 33740.8171
# Epoch 5/50:  45%|████▌     | 25/55 [00:00<00:00, 30.07it/s, loss=0.029, lr=9.77e-05]INFO:__main__:Gradient norm: 17625.7732
# Epoch 5/50:  45%|████▌     | 25/55 [00:00<00:00, 30.07it/s, loss=0.011, lr=9.79e-05]INFO:__main__:Gradient norm: 12921.9308
# Epoch 5/50:  53%|█████▎    | 29/55 [00:01<00:00, 29.77it/s, loss=0.024, lr=9.80e-05]INFO:__main__:Gradient norm: 26925.4641
# Epoch 5/50:  53%|█████▎    | 29/55 [00:01<00:00, 29.77it/s, loss=0.014, lr=9.82e-05]INFO:__main__:Gradient norm: 22598.7975
# Epoch 5/50:  53%|█████▎    | 29/55 [00:01<00:00, 29.77it/s, loss=0.016, lr=9.83e-05]INFO:__main__:Gradient norm: 59868.5394
# Epoch 5/50:  53%|█████▎    | 29/55 [00:01<00:00, 29.77it/s, loss=0.076, lr=9.85e-05]INFO:__main__:Gradient norm: 18505.2735
# Epoch 5/50:  60%|██████    | 33/55 [00:01<00:00, 30.61it/s, loss=0.011, lr=9.86e-05]INFO:__main__:Gradient norm: 14458.8626
# Epoch 5/50:  60%|██████    | 33/55 [00:01<00:00, 30.61it/s, loss=0.005, lr=9.87e-05]INFO:__main__:Gradient norm: 54975.5813
# Epoch 5/50:  60%|██████    | 33/55 [00:01<00:00, 30.61it/s, loss=0.048, lr=9.89e-05]INFO:__main__:Gradient norm: 16700.3550
# Epoch 5/50:  60%|██████    | 33/55 [00:01<00:00, 30.61it/s, loss=0.017, lr=9.90e-05]INFO:__main__:Gradient norm: 5762.0452
# Epoch 5/50:  67%|██████▋   | 37/55 [00:01<00:00, 30.59it/s, loss=0.003, lr=9.91e-05]INFO:__main__:Gradient norm: 17566.5852
# Epoch 5/50:  67%|██████▋   | 37/55 [00:01<00:00, 30.59it/s, loss=0.030, lr=9.92e-05]INFO:__main__:Gradient norm: 32866.7243
# Epoch 5/50:  67%|██████▋   | 37/55 [00:01<00:00, 30.59it/s, loss=0.022, lr=9.93e-05]INFO:__main__:Gradient norm: 20312.1273
# Epoch 5/50:  67%|██████▋   | 37/55 [00:01<00:00, 30.59it/s, loss=0.040, lr=9.94e-05]INFO:__main__:Gradient norm: 18643.8138
# Epoch 5/50:  75%|███████▍  | 41/55 [00:01<00:00, 30.35it/s, loss=0.005, lr=9.95e-05]INFO:__main__:Gradient norm: 24537.8384
# Epoch 5/50:  75%|███████▍  | 41/55 [00:01<00:00, 30.35it/s, loss=0.046, lr=9.95e-05]INFO:__main__:Gradient norm: 4569.1473
# Epoch 5/50:  75%|███████▍  | 41/55 [00:01<00:00, 30.35it/s, loss=0.003, lr=9.96e-05]INFO:__main__:Gradient norm: 32183.3456
# Epoch 5/50:  75%|███████▍  | 41/55 [00:01<00:00, 30.35it/s, loss=0.045, lr=9.97e-05]INFO:__main__:Gradient norm: 12932.4113
# Epoch 5/50:  82%|████████▏ | 45/55 [00:01<00:00, 30.41it/s, loss=0.011, lr=9.97e-05]INFO:__main__:Gradient norm: 6574.2231
# Epoch 5/50:  82%|████████▏ | 45/55 [00:01<00:00, 30.41it/s, loss=0.007, lr=9.98e-05]INFO:__main__:Gradient norm: 23245.0268
# Epoch 5/50:  82%|████████▏ | 45/55 [00:01<00:00, 30.41it/s, loss=0.029, lr=9.98e-05]INFO:__main__:Gradient norm: 12426.0858
# Epoch 5/50:  82%|████████▏ | 45/55 [00:01<00:00, 30.41it/s, loss=0.023, lr=9.99e-05]INFO:__main__:Gradient norm: 13321.7544
# Epoch 5/50:  89%|████████▉ | 49/55 [00:01<00:00, 30.59it/s, loss=0.024, lr=9.99e-05]INFO:__main__:Gradient norm: 15870.1495
# Epoch 5/50:  89%|████████▉ | 49/55 [00:01<00:00, 30.59it/s, loss=0.010, lr=9.99e-05]INFO:__main__:Gradient norm: 31423.7990
# Epoch 5/50:  89%|████████▉ | 49/55 [00:01<00:00, 30.59it/s, loss=0.021, lr=1.00e-04]INFO:__main__:Gradient norm: 23185.3777
# Epoch 5/50:  89%|████████▉ | 49/55 [00:01<00:00, 30.59it/s, loss=0.013, lr=1.00e-04]INFO:__main__:Gradient norm: 37728.9648
# Epoch 5/50:  96%|█████████▋| 53/55 [00:01<00:00, 30.02it/s, loss=0.047, lr=1.00e-04]INFO:__main__:Gradient norm: 48558.7547
# Epoch 5/50:  96%|█████████▋| 53/55 [00:01<00:00, 30.02it/s, loss=0.027, lr=1.00e-04]INFO:__main__:Gradient norm: 16343.0901
# Epoch 5/50: 100%|██████████| 55/55 [00:01<00:00, 29.56it/s, loss=0.012, lr=1.00e-04]
# INFO:__main__:New best model saved with validation loss: 0.0190
# INFO:__main__:Epoch 5: Train Loss = 0.0241, Val Loss = 0.0190, LR = 1.00e-04
# Epoch 6/50:   0%|          | 0/55 [00:00<?, ?it/s]INFO:__main__:Gradient norm: 5560.4376
# Epoch 6/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.006, lr=1.00e-04]INFO:__main__:Gradient norm: 48566.8203
# Epoch 6/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.033, lr=1.00e-04]INFO:__main__:Gradient norm: 18246.2038
# Epoch 6/50:   5%|▌         | 3/55 [00:00<00:01, 28.57it/s, loss=0.034, lr=1.00e-04]INFO:__main__:Gradient norm: 10800.5311
# Epoch 6/50:   5%|▌         | 3/55 [00:00<00:01, 28.57it/s, loss=0.006, lr=1.00e-04]INFO:__main__:Gradient norm: 14092.9972
# Epoch 6/50:   5%|▌         | 3/55 [00:00<00:01, 28.57it/s, loss=0.009, lr=1.00e-04]INFO:__main__:Gradient norm: 44209.1103
# Epoch 6/50:   5%|▌         | 3/55 [00:00<00:01, 28.57it/s, loss=0.049, lr=1.00e-04]INFO:__main__:Gradient norm: 4526.6413
# Epoch 6/50:  13%|█▎        | 7/55 [00:00<00:01, 29.39it/s, loss=0.003, lr=1.00e-04]INFO:__main__:Gradient norm: 23606.3141
# Epoch 6/50:  13%|█▎        | 7/55 [00:00<00:01, 29.39it/s, loss=0.014, lr=1.00e-04]INFO:__main__:Gradient norm: 42493.0718
# Epoch 6/50:  13%|█▎        | 7/55 [00:00<00:01, 29.39it/s, loss=0.092, lr=1.00e-04]INFO:__main__:Gradient norm: 16343.9841
# Epoch 6/50:  18%|█▊        | 10/55 [00:00<00:01, 29.29it/s, loss=0.038, lr=1.00e-04]INFO:__main__:Gradient norm: 19419.4415
# Epoch 6/50:  18%|█▊        | 10/55 [00:00<00:01, 29.29it/s, loss=0.032, lr=1.00e-04]INFO:__main__:Gradient norm: 11107.2897
# Epoch 6/50:  18%|█▊        | 10/55 [00:00<00:01, 29.29it/s, loss=0.030, lr=1.00e-04]INFO:__main__:Gradient norm: 39226.9813
# Epoch 6/50:  24%|██▎       | 13/55 [00:00<00:01, 29.02it/s, loss=0.025, lr=1.00e-04]INFO:__main__:Gradient norm: 17792.3885
# Epoch 6/50:  24%|██▎       | 13/55 [00:00<00:01, 29.02it/s, loss=0.013, lr=1.00e-04]INFO:__main__:Gradient norm: 14636.2083
# Epoch 6/50:  24%|██▎       | 13/55 [00:00<00:01, 29.02it/s, loss=0.033, lr=1.00e-04]INFO:__main__:Gradient norm: 9416.3486
# Epoch 6/50:  29%|██▉       | 16/55 [00:00<00:01, 27.23it/s, loss=0.010, lr=1.00e-04]INFO:__main__:Gradient norm: 9225.2068
# Epoch 6/50:  29%|██▉       | 16/55 [00:00<00:01, 27.23it/s, loss=0.005, lr=1.00e-04]INFO:__main__:Gradient norm: 11696.2625
# Epoch 6/50:  29%|██▉       | 16/55 [00:00<00:01, 27.23it/s, loss=0.008, lr=1.00e-04]INFO:__main__:Gradient norm: 23933.2732
# Epoch 6/50:  35%|███▍      | 19/55 [00:00<00:01, 27.57it/s, loss=0.013, lr=1.00e-04]INFO:__main__:Gradient norm: 15993.1915
# Epoch 6/50:  35%|███▍      | 19/55 [00:00<00:01, 27.57it/s, loss=0.018, lr=1.00e-04]INFO:__main__:Gradient norm: 12663.3959
# Epoch 6/50:  35%|███▍      | 19/55 [00:00<00:01, 27.57it/s, loss=0.013, lr=1.00e-04]INFO:__main__:Gradient norm: 8545.3585
# Epoch 6/50:  35%|███▍      | 19/55 [00:00<00:01, 27.57it/s, loss=0.017, lr=1.00e-04]INFO:__main__:Gradient norm: 15523.2698
# Epoch 6/50:  42%|████▏     | 23/55 [00:00<00:01, 28.49it/s, loss=0.016, lr=1.00e-04]INFO:__main__:Gradient norm: 12306.9761
# Epoch 6/50:  42%|████▏     | 23/55 [00:00<00:01, 28.49it/s, loss=0.007, lr=1.00e-04]INFO:__main__:Gradient norm: 11730.2155
# Epoch 6/50:  42%|████▏     | 23/55 [00:00<00:01, 28.49it/s, loss=0.002, lr=1.00e-04]INFO:__main__:Gradient norm: 9796.3165
# Epoch 6/50:  42%|████▏     | 23/55 [00:00<00:01, 28.49it/s, loss=0.010, lr=1.00e-04]INFO:__main__:Gradient norm: 40866.6113
# Epoch 6/50:  49%|████▉     | 27/55 [00:00<00:00, 29.26it/s, loss=0.037, lr=1.00e-04]INFO:__main__:Gradient norm: 18400.3002
# Epoch 6/50:  49%|████▉     | 27/55 [00:00<00:00, 29.26it/s, loss=0.012, lr=1.00e-04]INFO:__main__:Gradient norm: 8357.0922
# Epoch 6/50:  49%|████▉     | 27/55 [00:01<00:00, 29.26it/s, loss=0.008, lr=1.00e-04]INFO:__main__:Gradient norm: 30598.8903
# Epoch 6/50:  55%|█████▍    | 30/55 [00:01<00:00, 29.46it/s, loss=0.029, lr=1.00e-04]INFO:__main__:Gradient norm: 23230.2546
# Epoch 6/50:  55%|█████▍    | 30/55 [00:01<00:00, 29.46it/s, loss=0.014, lr=1.00e-04]INFO:__main__:Gradient norm: 31380.6698
# Epoch 6/50:  55%|█████▍    | 30/55 [00:01<00:00, 29.46it/s, loss=0.023, lr=1.00e-04]INFO:__main__:Gradient norm: 7122.3453
# Epoch 6/50:  60%|██████    | 33/55 [00:01<00:00, 29.28it/s, loss=0.010, lr=1.00e-04]INFO:__main__:Gradient norm: 13515.6334
# Epoch 6/50:  60%|██████    | 33/55 [00:01<00:00, 29.28it/s, loss=0.010, lr=1.00e-04]INFO:__main__:Gradient norm: 18245.5170
# Epoch 6/50:  60%|██████    | 33/55 [00:01<00:00, 29.28it/s, loss=0.019, lr=9.99e-05]INFO:__main__:Gradient norm: 25674.0665
# Epoch 6/50:  60%|██████    | 33/55 [00:01<00:00, 29.28it/s, loss=0.011, lr=9.99e-05]INFO:__main__:Gradient norm: 39993.3789
# Epoch 6/50:  67%|██████▋   | 37/55 [00:01<00:00, 29.79it/s, loss=0.035, lr=9.99e-05]INFO:__main__:Gradient norm: 17209.2476
# Epoch 6/50:  67%|██████▋   | 37/55 [00:01<00:00, 29.79it/s, loss=0.007, lr=9.99e-05]INFO:__main__:Gradient norm: 21178.9163
# Epoch 6/50:  67%|██████▋   | 37/55 [00:01<00:00, 29.79it/s, loss=0.064, lr=9.99e-05]INFO:__main__:Gradient norm: 12426.1115
# Epoch 6/50:  67%|██████▋   | 37/55 [00:01<00:00, 29.79it/s, loss=0.011, lr=9.99e-05]INFO:__main__:Gradient norm: 12654.7909
# Epoch 6/50:  75%|███████▍  | 41/55 [00:01<00:00, 29.96it/s, loss=0.006, lr=9.99e-05]INFO:__main__:Gradient norm: 11516.5033
# Epoch 6/50:  75%|███████▍  | 41/55 [00:01<00:00, 29.96it/s, loss=0.014, lr=9.99e-05]INFO:__main__:Gradient norm: 16371.1070
# Epoch 6/50:  75%|███████▍  | 41/55 [00:01<00:00, 29.96it/s, loss=0.006, lr=9.99e-05]INFO:__main__:Gradient norm: 7525.9448
# Epoch 6/50:  80%|████████  | 44/55 [00:01<00:00, 29.73it/s, loss=0.004, lr=9.99e-05]INFO:__main__:Gradient norm: 7675.6054
# Epoch 6/50:  80%|████████  | 44/55 [00:01<00:00, 29.73it/s, loss=0.006, lr=9.99e-05]INFO:__main__:Gradient norm: 20459.8983
# Epoch 6/50:  80%|████████  | 44/55 [00:01<00:00, 29.73it/s, loss=0.024, lr=9.99e-05]INFO:__main__:Gradient norm: 12120.7462
# Epoch 6/50:  85%|████████▌ | 47/55 [00:01<00:00, 29.49it/s, loss=0.004, lr=9.99e-05]INFO:__main__:Gradient norm: 26399.5930
# Epoch 6/50:  85%|████████▌ | 47/55 [00:01<00:00, 29.49it/s, loss=0.041, lr=9.99e-05]INFO:__main__:Gradient norm: 9413.7545
# Epoch 6/50:  85%|████████▌ | 47/55 [00:01<00:00, 29.49it/s, loss=0.016, lr=9.99e-05]INFO:__main__:Gradient norm: 26279.7524
# Epoch 6/50:  85%|████████▌ | 47/55 [00:01<00:00, 29.49it/s, loss=0.015, lr=9.99e-05]INFO:__main__:Gradient norm: 22881.7273
# Epoch 6/50:  93%|█████████▎| 51/55 [00:01<00:00, 30.07it/s, loss=0.011, lr=9.99e-05]INFO:__main__:Gradient norm: 21432.3050
# Epoch 6/50:  93%|█████████▎| 51/55 [00:01<00:00, 30.07it/s, loss=0.020, lr=9.99e-05]INFO:__main__:Gradient norm: 8581.5945
# Epoch 6/50:  93%|█████████▎| 51/55 [00:01<00:00, 30.07it/s, loss=0.009, lr=9.99e-05]INFO:__main__:Gradient norm: 15464.7337
# Epoch 6/50:  98%|█████████▊| 54/55 [00:01<00:00, 29.73it/s, loss=0.016, lr=9.99e-05]INFO:__main__:Gradient norm: 10287.0589
# Epoch 6/50: 100%|██████████| 55/55 [00:01<00:00, 29.29it/s, loss=0.003, lr=9.99e-05]
# INFO:__main__:Epoch 6: Train Loss = 0.0186, Val Loss = 0.0194, LR = 9.99e-05
# Epoch 7/50:   0%|          | 0/55 [00:00<?, ?it/s]INFO:__main__:Gradient norm: 33847.8703
# Epoch 7/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.026, lr=9.99e-05]INFO:__main__:Gradient norm: 36905.6484
# Epoch 7/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.014, lr=9.99e-05]INFO:__main__:Gradient norm: 20277.7992
# Epoch 7/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.016, lr=9.99e-05]INFO:__main__:Gradient norm: 14830.1939
# Epoch 7/50:   7%|▋         | 4/55 [00:00<00:01, 30.31it/s, loss=0.028, lr=9.99e-05]INFO:__main__:Gradient norm: 10679.4889
# Epoch 7/50:   7%|▋         | 4/55 [00:00<00:01, 30.31it/s, loss=0.008, lr=9.99e-05]INFO:__main__:Gradient norm: 6638.0556
# Epoch 7/50:   7%|▋         | 4/55 [00:00<00:01, 30.31it/s, loss=0.007, lr=9.98e-05]INFO:__main__:Gradient norm: 26859.1135
# Epoch 7/50:   7%|▋         | 4/55 [00:00<00:01, 30.31it/s, loss=0.017, lr=9.98e-05]INFO:__main__:Gradient norm: 31242.0429
# Epoch 7/50:  15%|█▍        | 8/55 [00:00<00:01, 26.94it/s, loss=0.026, lr=9.98e-05]INFO:__main__:Gradient norm: 13852.2739
# Epoch 7/50:  15%|█▍        | 8/55 [00:00<00:01, 26.94it/s, loss=0.007, lr=9.98e-05]INFO:__main__:Gradient norm: 19145.6933
# Epoch 7/50:  15%|█▍        | 8/55 [00:00<00:01, 26.94it/s, loss=0.028, lr=9.98e-05]INFO:__main__:Gradient norm: 30557.3816
# Epoch 7/50:  15%|█▍        | 8/55 [00:00<00:01, 26.94it/s, loss=0.027, lr=9.98e-05]INFO:__main__:Gradient norm: 17794.1575
# Epoch 7/50:  22%|██▏       | 12/55 [00:00<00:01, 28.57it/s, loss=0.015, lr=9.98e-05]INFO:__main__:Gradient norm: 7067.3298
# Epoch 7/50:  22%|██▏       | 12/55 [00:00<00:01, 28.57it/s, loss=0.008, lr=9.98e-05]INFO:__main__:Gradient norm: 21386.3189
# Epoch 7/50:  22%|██▏       | 12/55 [00:00<00:01, 28.57it/s, loss=0.014, lr=9.98e-05]INFO:__main__:Gradient norm: 22970.3469
# Epoch 7/50:  22%|██▏       | 12/55 [00:00<00:01, 28.57it/s, loss=0.009, lr=9.98e-05]INFO:__main__:Gradient norm: 13107.9627
# Epoch 7/50:  29%|██▉       | 16/55 [00:00<00:01, 29.57it/s, loss=0.025, lr=9.98e-05]INFO:__main__:Gradient norm: 3357.6741
# Epoch 7/50:  29%|██▉       | 16/55 [00:00<00:01, 29.57it/s, loss=0.001, lr=9.98e-05]INFO:__main__:Gradient norm: 17292.3785
# Epoch 7/50:  29%|██▉       | 16/55 [00:00<00:01, 29.57it/s, loss=0.008, lr=9.98e-05]INFO:__main__:Gradient norm: 32702.4188
# Epoch 7/50:  35%|███▍      | 19/55 [00:00<00:01, 29.35it/s, loss=0.054, lr=9.98e-05]INFO:__main__:Gradient norm: 14480.2037
# Epoch 7/50:  35%|███▍      | 19/55 [00:00<00:01, 29.35it/s, loss=0.017, lr=9.98e-05]INFO:__main__:Gradient norm: 13632.8964
# Epoch 7/50:  35%|███▍      | 19/55 [00:00<00:01, 29.35it/s, loss=0.044, lr=9.98e-05]INFO:__main__:Gradient norm: 8167.6183
# Epoch 7/50:  35%|███▍      | 19/55 [00:00<00:01, 29.35it/s, loss=0.010, lr=9.98e-05]INFO:__main__:Gradient norm: 15745.7383
# Epoch 7/50:  42%|████▏     | 23/55 [00:00<00:01, 30.68it/s, loss=0.011, lr=9.97e-05]INFO:__main__:Gradient norm: 14815.3970
# Epoch 7/50:  42%|████▏     | 23/55 [00:00<00:01, 30.68it/s, loss=0.020, lr=9.97e-05]INFO:__main__:Gradient norm: 12808.2531
# Epoch 7/50:  42%|████▏     | 23/55 [00:00<00:01, 30.68it/s, loss=0.006, lr=9.97e-05]INFO:__main__:Gradient norm: 11403.9039
# Epoch 7/50:  42%|████▏     | 23/55 [00:00<00:01, 30.68it/s, loss=0.011, lr=9.97e-05]INFO:__main__:Gradient norm: 20479.9660
# Epoch 7/50:  49%|████▉     | 27/55 [00:00<00:00, 30.47it/s, loss=0.008, lr=9.97e-05]INFO:__main__:Gradient norm: 11369.0609
# Epoch 7/50:  49%|████▉     | 27/55 [00:00<00:00, 30.47it/s, loss=0.011, lr=9.97e-05]INFO:__main__:Gradient norm: 14931.4562
# Epoch 7/50:  49%|████▉     | 27/55 [00:00<00:00, 30.47it/s, loss=0.019, lr=9.97e-05]INFO:__main__:Gradient norm: 30462.4394
# Epoch 7/50:  49%|████▉     | 27/55 [00:01<00:00, 30.47it/s, loss=0.046, lr=9.97e-05]INFO:__main__:Gradient norm: 18198.7408
# Epoch 7/50:  56%|█████▋    | 31/55 [00:01<00:00, 30.19it/s, loss=0.008, lr=9.97e-05]INFO:__main__:Gradient norm: 20027.5332
# Epoch 7/50:  56%|█████▋    | 31/55 [00:01<00:00, 30.19it/s, loss=0.007, lr=9.97e-05]INFO:__main__:Gradient norm: 16507.4098
# Epoch 7/50:  56%|█████▋    | 31/55 [00:01<00:00, 30.19it/s, loss=0.026, lr=9.97e-05]INFO:__main__:Gradient norm: 14879.4479
# Epoch 7/50:  56%|█████▋    | 31/55 [00:01<00:00, 30.19it/s, loss=0.007, lr=9.97e-05]INFO:__main__:Gradient norm: 4591.1361
# Epoch 7/50:  64%|██████▎   | 35/55 [00:01<00:00, 30.23it/s, loss=0.003, lr=9.97e-05]INFO:__main__:Gradient norm: 83329.0919
# Epoch 7/50:  64%|██████▎   | 35/55 [00:01<00:00, 30.23it/s, loss=0.059, lr=9.97e-05]INFO:__main__:Gradient norm: 28498.9059
# Epoch 7/50:  64%|██████▎   | 35/55 [00:01<00:00, 30.23it/s, loss=0.019, lr=9.97e-05]INFO:__main__:Gradient norm: 28873.5981
# ...
# Epoch 24/50:  75%|███████▍  | 41/55 [00:01<00:00, 28.04it/s, loss=0.020, lr=6.29e-05]INFO:__main__:Gradient norm: 7635.5274
# Epoch 24/50:  75%|███████▍  | 41/55 [00:01<00:00, 28.04it/s, loss=0.008, lr=6.28e-05]INFO:__main__:Gradient norm: 8166.3780
# Epoch 24/50:  75%|███████▍  | 41/55 [00:01<00:00, 28.04it/s, loss=0.011, lr=6.28e-05]INFO:__main__:Gradient norm: 30595.4975
# Epoch 24/50:  80%|████████  | 44/55 [00:01<00:00, 25.12it/s, loss=0.030, lr=6.27e-05]INFO:__main__:Gradient norm: 9094.4593
# Epoch 24/50:  80%|████████  | 44/55 [00:01<00:00, 25.12it/s, loss=0.012, lr=6.27e-05]INFO:__main__:Gradient norm: 33970.7987
# Epoch 24/50:  80%|████████  | 44/55 [00:01<00:00, 25.12it/s, loss=0.031, lr=6.26e-05]INFO:__main__:Gradient norm: 28027.3038
# Epoch 24/50:  85%|████████▌ | 47/55 [00:01<00:00, 25.46it/s, loss=0.015, lr=6.25e-05]INFO:__main__:Gradient norm: 17538.2040
# Epoch 24/50:  85%|████████▌ | 47/55 [00:01<00:00, 25.46it/s, loss=0.008, lr=6.25e-05]INFO:__main__:Gradient norm: 17698.4236
# Epoch 24/50:  85%|████████▌ | 47/55 [00:01<00:00, 25.46it/s, loss=0.010, lr=6.24e-05]INFO:__main__:Gradient norm: 13753.2904
# Epoch 24/50:  91%|█████████ | 50/55 [00:01<00:00, 26.51it/s, loss=0.036, lr=6.23e-05]INFO:__main__:Gradient norm: 6734.1048
# Epoch 24/50:  91%|█████████ | 50/55 [00:01<00:00, 26.51it/s, loss=0.013, lr=6.23e-05]INFO:__main__:Gradient norm: 13401.7902
# Epoch 24/50:  91%|█████████ | 50/55 [00:01<00:00, 26.51it/s, loss=0.010, lr=6.22e-05]INFO:__main__:Gradient norm: 15964.5947
# Epoch 24/50:  96%|█████████▋| 53/55 [00:02<00:00, 27.38it/s, loss=0.007, lr=6.22e-05]INFO:__main__:Gradient norm: 10425.3365
# Epoch 24/50:  96%|█████████▋| 53/55 [00:02<00:00, 27.38it/s, loss=0.019, lr=6.21e-05]INFO:__main__:Gradient norm: 54921.7554
# Epoch 24/50: 100%|██████████| 55/55 [00:02<00:00, 26.34it/s, loss=0.018, lr=6.20e-05]
# INFO:__main__:Epoch 24: Train Loss = 0.0146, Val Loss = 0.0166, LR = 6.20e-05
# Epoch 25/50:   0%|          | 0/55 [00:00<?, ?it/s]INFO:__main__:Gradient norm: 12880.9631
# Epoch 25/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.009, lr=6.20e-05]INFO:__main__:Gradient norm: 39974.0542
# Epoch 25/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.022, lr=6.19e-05]INFO:__main__:Gradient norm: 16750.9398
# Epoch 25/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.027, lr=6.19e-05]INFO:__main__:Gradient norm: 22848.5415
# Epoch 25/50:   7%|▋         | 4/55 [00:00<00:01, 29.63it/s, loss=0.014, lr=6.18e-05]INFO:__main__:Gradient norm: 14496.8323
# Epoch 25/50:   7%|▋         | 4/55 [00:00<00:01, 29.63it/s, loss=0.037, lr=6.17e-05]INFO:__main__:Gradient norm: 19591.1420
# Epoch 25/50:   7%|▋         | 4/55 [00:00<00:01, 29.63it/s, loss=0.009, lr=6.17e-05]INFO:__main__:Gradient norm: 8427.3511
# Epoch 25/50:  13%|█▎        | 7/55 [00:00<00:01, 28.09it/s, loss=0.009, lr=6.16e-05]INFO:__main__:Gradient norm: 7860.4669
# Epoch 25/50:  13%|█▎        | 7/55 [00:00<00:01, 28.09it/s, loss=0.020, lr=6.15e-05]INFO:__main__:Gradient norm: 22109.2115
# Epoch 25/50:  13%|█▎        | 7/55 [00:00<00:01, 28.09it/s, loss=0.011, lr=6.15e-05]INFO:__main__:Gradient norm: 14461.1540
# Epoch 25/50:  18%|█▊        | 10/55 [00:00<00:01, 28.29it/s, loss=0.037, lr=6.14e-05]INFO:__main__:Gradient norm: 9225.7881
# Epoch 25/50:  18%|█▊        | 10/55 [00:00<00:01, 28.29it/s, loss=0.003, lr=6.14e-05]INFO:__main__:Gradient norm: 40249.7541
# Epoch 25/50:  18%|█▊        | 10/55 [00:00<00:01, 28.29it/s, loss=0.033, lr=6.13e-05]INFO:__main__:Gradient norm: 10335.9438
# Epoch 25/50:  18%|█▊        | 10/55 [00:00<00:01, 28.29it/s, loss=0.016, lr=6.12e-05]INFO:__main__:Gradient norm: 4987.6456
# Epoch 25/50:  25%|██▌       | 14/55 [00:00<00:01, 28.42it/s, loss=0.006, lr=6.12e-05]INFO:__main__:Gradient norm: 18487.4920
# Epoch 25/50:  25%|██▌       | 14/55 [00:00<00:01, 28.42it/s, loss=0.004, lr=6.11e-05]INFO:__main__:Gradient norm: 5237.8087
# Epoch 25/50:  25%|██▌       | 14/55 [00:00<00:01, 28.42it/s, loss=0.003, lr=6.10e-05]INFO:__main__:Gradient norm: 9467.3248
# Epoch 25/50:  25%|██▌       | 14/55 [00:00<00:01, 28.42it/s, loss=0.006, lr=6.10e-05]INFO:__main__:Gradient norm: 18591.3994
# Epoch 25/50:  33%|███▎      | 18/55 [00:00<00:01, 29.37it/s, loss=0.005, lr=6.09e-05]INFO:__main__:Gradient norm: 21471.9062
# Epoch 25/50:  33%|███▎      | 18/55 [00:00<00:01, 29.37it/s, loss=0.006, lr=6.09e-05]INFO:__main__:Gradient norm: 11568.3689
# Epoch 25/50:  33%|███▎      | 18/55 [00:00<00:01, 29.37it/s, loss=0.009, lr=6.08e-05]INFO:__main__:Gradient norm: 32754.7165
# Epoch 25/50:  33%|███▎      | 18/55 [00:00<00:01, 29.37it/s, loss=0.061, lr=6.07e-05]INFO:__main__:Gradient norm: 8347.9029
# Epoch 25/50:  40%|████      | 22/55 [00:00<00:01, 29.01it/s, loss=0.006, lr=6.07e-05]INFO:__main__:Gradient norm: 15036.4756
# Epoch 25/50:  40%|████      | 22/55 [00:00<00:01, 29.01it/s, loss=0.020, lr=6.06e-05]INFO:__main__:Gradient norm: 5020.0824
# Epoch 25/50:  40%|████      | 22/55 [00:00<00:01, 29.01it/s, loss=0.004, lr=6.06e-05]INFO:__main__:Gradient norm: 18559.5737
# Epoch 25/50:  45%|████▌     | 25/55 [00:00<00:01, 27.70it/s, loss=0.036, lr=6.05e-05]INFO:__main__:Gradient norm: 5354.8665
# Epoch 25/50:  45%|████▌     | 25/55 [00:00<00:01, 27.70it/s, loss=0.006, lr=6.04e-05]INFO:__main__:Gradient norm: 17678.3764
# Epoch 25/50:  45%|████▌     | 25/55 [00:00<00:01, 27.70it/s, loss=0.040, lr=6.04e-05]INFO:__main__:Gradient norm: 4394.4816
# Epoch 25/50:  51%|█████     | 28/55 [00:01<00:01, 26.47it/s, loss=0.005, lr=6.03e-05]INFO:__main__:Gradient norm: 42200.1511
# Epoch 25/50:  51%|█████     | 28/55 [00:01<00:01, 26.47it/s, loss=0.037, lr=6.02e-05]INFO:__main__:Gradient norm: 12269.1591
# Epoch 25/50:  51%|█████     | 28/55 [00:01<00:01, 26.47it/s, loss=0.009, lr=6.02e-05]INFO:__main__:Gradient norm: 8916.8088
# Epoch 25/50:  51%|█████     | 28/55 [00:01<00:01, 26.47it/s, loss=0.004, lr=6.01e-05]INFO:__main__:Gradient norm: 6320.5075
# Epoch 25/50:  58%|█████▊    | 32/55 [00:01<00:00, 28.04it/s, loss=0.005, lr=6.01e-05]INFO:__main__:Gradient norm: 6144.7512
# Epoch 25/50:  58%|█████▊    | 32/55 [00:01<00:00, 28.04it/s, loss=0.008, lr=6.00e-05]INFO:__main__:Gradient norm: 53059.3250
# Epoch 25/50:  58%|█████▊    | 32/55 [00:01<00:00, 28.04it/s, loss=0.047, lr=5.99e-05]INFO:__main__:Gradient norm: 22576.8810
# Epoch 25/50:  58%|█████▊    | 32/55 [00:01<00:00, 28.04it/s, loss=0.021, lr=5.99e-05]INFO:__main__:Gradient norm: 6643.7065
# Epoch 25/50:  65%|██████▌   | 36/55 [00:01<00:00, 28.62it/s, loss=0.017, lr=5.98e-05]INFO:__main__:Gradient norm: 17580.9059
# Epoch 25/50:  65%|██████▌   | 36/55 [00:01<00:00, 28.62it/s, loss=0.005, lr=5.97e-05]INFO:__main__:Gradient norm: 11199.2970
# Epoch 25/50:  65%|██████▌   | 36/55 [00:01<00:00, 28.62it/s, loss=0.036, lr=5.97e-05]INFO:__main__:Gradient norm: 35390.5849
# Epoch 25/50:  71%|███████   | 39/55 [00:01<00:00, 28.83it/s, loss=0.021, lr=5.96e-05]INFO:__main__:Gradient norm: 11732.2442
# Epoch 25/50:  71%|███████   | 39/55 [00:01<00:00, 28.83it/s, loss=0.008, lr=5.96e-05]INFO:__main__:Gradient norm: 32292.3523
# Epoch 25/50:  71%|███████   | 39/55 [00:01<00:00, 28.83it/s, loss=0.011, lr=5.95e-05]INFO:__main__:Gradient norm: 8079.1375
# Epoch 25/50:  71%|███████   | 39/55 [00:01<00:00, 28.83it/s, loss=0.002, lr=5.94e-05]INFO:__main__:Gradient norm: 12241.8755
# Epoch 25/50:  78%|███████▊  | 43/55 [00:01<00:00, 29.74it/s, loss=0.031, lr=5.94e-05]INFO:__main__:Gradient norm: 7397.5215
# Epoch 25/50:  78%|███████▊  | 43/55 [00:01<00:00, 29.74it/s, loss=0.008, lr=5.93e-05]INFO:__main__:Gradient norm: 19965.6437
# Epoch 25/50:  78%|███████▊  | 43/55 [00:01<00:00, 29.74it/s, loss=0.006, lr=5.92e-05]INFO:__main__:Gradient norm: 10542.2616
# Epoch 25/50:  84%|████████▎ | 46/55 [00:01<00:00, 29.65it/s, loss=0.006, lr=5.92e-05]INFO:__main__:Gradient norm: 16012.3393
# Epoch 25/50:  84%|████████▎ | 46/55 [00:01<00:00, 29.65it/s, loss=0.008, lr=5.91e-05]INFO:__main__:Gradient norm: 20106.3698
# Epoch 25/50:  84%|████████▎ | 46/55 [00:01<00:00, 29.65it/s, loss=0.009, lr=5.91e-05]INFO:__main__:Gradient norm: 5469.2909
# Epoch 25/50:  89%|████████▉ | 49/55 [00:01<00:00, 28.51it/s, loss=0.004, lr=5.90e-05]INFO:__main__:Gradient norm: 8144.7810
# Epoch 25/50:  89%|████████▉ | 49/55 [00:01<00:00, 28.51it/s, loss=0.004, lr=5.89e-05]INFO:__main__:Gradient norm: 24421.7301
# Epoch 25/50:  89%|████████▉ | 49/55 [00:01<00:00, 28.51it/s, loss=0.014, lr=5.89e-05]INFO:__main__:Gradient norm: 6771.6621
# Epoch 25/50:  95%|█████████▍| 52/55 [00:01<00:00, 23.20it/s, loss=0.012, lr=5.88e-05]INFO:__main__:Gradient norm: 30537.5016
# Epoch 25/50:  95%|█████████▍| 52/55 [00:01<00:00, 23.20it/s, loss=0.016, lr=5.87e-05]INFO:__main__:Gradient norm: 4714.8946
# Epoch 25/50:  95%|█████████▍| 52/55 [00:01<00:00, 23.20it/s, loss=0.003, lr=5.87e-05]INFO:__main__:Gradient norm: 74315.0629
# Epoch 25/50: 100%|██████████| 55/55 [00:02<00:00, 27.08it/s, loss=0.092, lr=5.86e-05]
# INFO:__main__:Epoch 25: Train Loss = 0.0165, Val Loss = 0.0166, LR = 5.86e-05
# Epoch 26/50:   0%|          | 0/55 [00:00<?, ?it/s]INFO:__main__:Gradient norm: 5880.2296
# Epoch 26/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.004, lr=5.86e-05]INFO:__main__:Gradient norm: 9665.0840
# Epoch 26/50:   0%|          | 0/55 [00:00<?, ?it/s, loss=0.015, lr=5.85e-05]INFO:__main__:Gradient norm: 5632.3359
# Epoch 26/50:   5%|▌         | 3/55 [00:00<00:02, 24.39it/s, loss=0.003, lr=5.84e-05]INFO:__main__:Gradient norm: 17981.6402
# Epoch 26/50:   5%|▌         | 3/55 [00:00<00:02, 24.39it/s, loss=0.010, lr=5.84e-05]INFO:__main__:Gradient norm: 21253.6390
# Epoch 26/50:   5%|▌         | 3/55 [00:00<00:02, 24.39it/s, loss=0.034, lr=5.83e-05]INFO:__main__:Gradient norm: 10428.3646
# Epoch 26/50:  11%|█         | 6/55 [00:00<00:01, 26.01it/s, loss=0.011, lr=5.82e-05]INFO:__main__:Gradient norm: 10851.0070
# Epoch 26/50:  11%|█         | 6/55 [00:00<00:01, 26.01it/s, loss=0.010, lr=5.82e-05]INFO:__main__:Gradient norm: 9964.2717
# Epoch 26/50:  11%|█         | 6/55 [00:00<00:01, 26.01it/s, loss=0.007, lr=5.81e-05]INFO:__main__:Gradient norm: 13071.3627
# Epoch 26/50:  16%|█▋        | 9/55 [00:00<00:01, 26.25it/s, loss=0.007, lr=5.81e-05]INFO:__main__:Gradient norm: 12261.5128
# Epoch 26/50:  16%|█▋        | 9/55 [00:00<00:01, 26.25it/s, loss=0.008, lr=5.80e-05]INFO:__main__:Gradient norm: 16938.2198
# Epoch 26/50:  16%|█▋        | 9/55 [00:00<00:01, 26.25it/s, loss=0.008, lr=5.79e-05]INFO:__main__:Gradient norm: 59563.0671
# Epoch 26/50:  22%|██▏       | 12/55 [00:00<00:01, 26.19it/s, loss=0.041, lr=5.79e-05]INFO:__main__:Gradient norm: 9636.1110
# Epoch 26/50:  22%|██▏       | 12/55 [00:00<00:01, 26.19it/s, loss=0.017, lr=5.78e-05]INFO:__main__:Gradient norm: 3825.7995
# Epoch 26/50:  22%|██▏       | 12/55 [00:00<00:01, 26.19it/s, loss=0.004, lr=5.77e-05]INFO:__main__:Gradient norm: 18010.2864
# Epoch 26/50:  27%|██▋       | 15/55 [00:00<00:01, 23.56it/s, loss=0.007, lr=5.77e-05]INFO:__main__:Gradient norm: 14557.0897
# Epoch 26/50:  27%|██▋       | 15/55 [00:00<00:01, 23.56it/s, loss=0.029, lr=5.76e-05]INFO:__main__:Gradient norm: 18797.7718
# Epoch 26/50:  27%|██▋       | 15/55 [00:00<00:01, 23.56it/s, loss=0.018, lr=5.76e-05]INFO:__main__:Gradient norm: 30669.0492
# Epoch 26/50:  33%|███▎      | 18/55 [00:00<00:01, 24.63it/s, loss=0.029, lr=5.75e-05]INFO:__main__:Gradient norm: 31328.0649
# Epoch 26/50:  33%|███▎      | 18/55 [00:00<00:01, 24.63it/s, loss=0.014, lr=5.74e-05]INFO:__main__:Gradient norm: 17890.3810
# Epoch 26/50:  33%|███▎      | 18/55 [00:00<00:01, 24.63it/s, loss=0.016, lr=5.74e-05]INFO:__main__:Gradient norm: 14335.0064
# Epoch 26/50:  38%|███▊      | 21/55 [00:00<00:01, 25.87it/s, loss=0.044, lr=5.73e-05]INFO:__main__:Gradient norm: 8470.9997
# Epoch 26/50:  38%|███▊      | 21/55 [00:00<00:01, 25.87it/s, loss=0.011, lr=5.72e-05]INFO:__main__:Gradient norm: 11984.4458
# Epoch 26/50:  38%|███▊      | 21/55 [00:00<00:01, 25.87it/s, loss=0.004, lr=5.72e-05]INFO:__main__:Gradient norm: 7693.7039
# Epoch 26/50:  38%|███▊      | 21/55 [00:00<00:01, 25.87it/s, loss=0.013, lr=5.71e-05]INFO:__main__:Gradient norm: 9686.5498
# Epoch 26/50:  45%|████▌     | 25/55 [00:00<00:01, 27.85it/s, loss=0.011, lr=5.71e-05]INFO:__main__:Gradient norm: 6735.3254
# Epoch 26/50:  45%|████▌     | 25/55 [00:00<00:01, 27.85it/s, loss=0.011, lr=5.70e-05]INFO:__main__:Gradient norm: 6807.1166
# Epoch 26/50:  45%|████▌     | 25/55 [00:01<00:01, 27.85it/s, loss=0.006, lr=5.69e-05]INFO:__main__:Gradient norm: 21490.8779
# Epoch 26/50:  51%|█████     | 28/55 [00:01<00:00, 28.13it/s, loss=0.016, lr=5.69e-05]INFO:__main__:Gradient norm: 15700.2802
# Epoch 26/50:  51%|█████     | 28/55 [00:01<00:00, 28.13it/s, loss=0.028, lr=5.68e-05]INFO:__main__:Gradient norm: 26249.3774
# Epoch 26/50:  51%|█████     | 28/55 [00:01<00:00, 28.13it/s, loss=0.011, lr=5.67e-05]INFO:__main__:Gradient norm: 5984.7855
# Epoch 26/50:  56%|█████▋    | 31/55 [00:01<00:00, 25.89it/s, loss=0.007, lr=5.67e-05]INFO:__main__:Gradient norm: 11000.3281
# Epoch 26/50:  56%|█████▋    | 31/55 [00:01<00:00, 25.89it/s, loss=0.015, lr=5.66e-05]INFO:__main__:Gradient norm: 19623.3687
# Epoch 26/50:  56%|█████▋    | 31/55 [00:01<00:00, 25.89it/s, loss=0.007, lr=5.66e-05]INFO:__main__:Gradient norm: 24345.9320
# Epoch 26/50:  56%|█████▋    | 31/55 [00:01<00:00, 25.89it/s, loss=0.036, lr=5.65e-05]INFO:__main__:Gradient norm: 12607.8386
# Epoch 26/50:  64%|██████▎   | 35/55 [00:01<00:00, 28.15it/s, loss=0.003, lr=5.64e-05]INFO:__main__:Gradient norm: 13645.4011
# Epoch 26/50:  64%|██████▎   | 35/55 [00:01<00:00, 28.15it/s, loss=0.014, lr=5.64e-05]INFO:__main__:Gradient norm: 14380.3087
# Epoch 26/50:  64%|██████▎   | 35/55 [00:01<00:00, 28.15it/s, loss=0.009, lr=5.63e-05]INFO:__main__:Gradient norm: 5469.7007
# Epoch 26/50:  64%|██████▎   | 35/55 [00:01<00:00, 28.15it/s, loss=0.010, lr=5.62e-05]INFO:__main__:Gradient norm: 6560.1212
# Epoch 26/50:  71%|███████   | 39/55 [00:01<00:00, 29.87it/s, loss=0.012, lr=5.62e-05]INFO:__main__:Gradient norm: 28170.9592
# Epoch 26/50:  71%|███████   | 39/55 [00:01<00:00, 29.87it/s, loss=0.020, lr=5.61e-05]INFO:__main__:Gradient norm: 14923.4649
# Epoch 26/50:  71%|███████   | 39/55 [00:01<00:00, 29.87it/s, loss=0.009, lr=5.60e-05]INFO:__main__:Gradient norm: 5843.8764
# Epoch 26/50:  71%|███████   | 39/55 [00:01<00:00, 29.87it/s, loss=0.007, lr=5.60e-05]INFO:__main__:Gradient norm: 7209.7532
# Epoch 26/50:  78%|███████▊  | 43/55 [00:01<00:00, 30.76it/s, loss=0.009, lr=5.59e-05]INFO:__main__:Gradient norm: 5755.9930
# Epoch 26/50:  78%|███████▊  | 43/55 [00:01<00:00, 30.76it/s, loss=0.009, lr=5.59e-05]INFO:__main__:Gradient norm: 6698.7843
# Epoch 26/50:  78%|███████▊  | 43/55 [00:01<00:00, 30.76it/s, loss=0.013, lr=5.58e-05]INFO:__main__:Gradient norm: 19667.5684
# Epoch 26/50:  78%|███████▊  | 43/55 [00:01<00:00, 30.76it/s, loss=0.010, lr=5.57e-05]INFO:__main__:Gradient norm: 13688.5875
# Epoch 26/50:  85%|████████▌ | 47/55 [00:01<00:00, 31.30it/s, loss=0.005, lr=5.57e-05]INFO:__main__:Gradient norm: 4751.3585
# Epoch 26/50:  85%|████████▌ | 47/55 [00:01<00:00, 31.30it/s, loss=0.006, lr=5.56e-05]INFO:__main__:Gradient norm: 21640.2375
# Epoch 26/50:  85%|████████▌ | 47/55 [00:01<00:00, 31.30it/s, loss=0.062, lr=5.55e-05]INFO:__main__:Gradient norm: 16305.0583
# Epoch 26/50:  85%|████████▌ | 47/55 [00:01<00:00, 31.30it/s, loss=0.016, lr=5.55e-05]INFO:__main__:Gradient norm: 10284.5353
# Epoch 26/50:  93%|█████████▎| 51/55 [00:01<00:00, 29.55it/s, loss=0.006, lr=5.54e-05]INFO:__main__:Gradient norm: 27068.0725
# Epoch 26/50:  93%|█████████▎| 51/55 [00:01<00:00, 29.55it/s, loss=0.037, lr=5.54e-05]INFO:__main__:Gradient norm: 11535.0744
# Epoch 26/50:  93%|█████████▎| 51/55 [00:01<00:00, 29.55it/s, loss=0.025, lr=5.53e-05]INFO:__main__:Gradient norm: 35552.1575
# Epoch 26/50:  93%|█████████▎| 51/55 [00:01<00:00, 29.55it/s, loss=0.025, lr=5.52e-05]INFO:__main__:Gradient norm: 12501.8534
# Epoch 26/50: 100%|██████████| 55/55 [00:01<00:00, 28.28it/s, loss=0.004, lr=5.52e-05]
# INFO:__main__:Epoch 26: Train Loss = 0.0150, Val Loss = 0.0168, LR = 5.52e-05
# INFO:__main__:Early stopping triggered after 26 epochs

# %%
def test_model_predictions(
    checkpoint_path="checkpoints/milb_batter_model.pth", 
    target_scaler_path="milb_batter_target_scaler.pkl",
    num_examples=5
):
    """Test model predictions with loaded checkpoint and inverse scaling"""
    # Load checkpoint and scaler
    checkpoint = torch.load(checkpoint_path, map_location='cpu')
    target_scaler = joblib.load(target_scaler_path)
    
    # Get feature weights from config
    feature_weights = DataConfig().input_weights
    
    # Create model with same configuration as training
    model = ImprovedLSTM(
        input_size=len(INPUT_FEATURES),
        hidden_size=256,
        num_layers=2,
        output_size=len(TARGET_FEATURES),
        dropout=0.2,
        bidirectional=True,
        num_heads=4,
        feature_weights=feature_weights
    ).cpu()
    
    # Load state dict
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    
    # Get sample data
    data, masks, targets = next(iter(valid_loader))
    data = data.squeeze(1)
    
    logger.info("\nModel Prediction Examples:")
    with torch.no_grad():
        # Get scaled predictions
        scaled_outputs = model(data, masks.sum(1).clamp(min=1))
        
        # Inverse transform predictions and targets
        predictions = target_scaler.inverse_transform(scaled_outputs.cpu().numpy())
        actuals = target_scaler.inverse_transform(targets.cpu().numpy())
        
        for i in range(min(num_examples, len(data))):
            logger.info(f"\nExample {i+1}:")
            logger.info("Feature Contributions (Last Sequence Value):")
            
            # Show weighted feature values for the last timestep
            feature_values = data[i, -1].cpu().numpy()  # Get last timestep
            for feat_idx, feature in enumerate(INPUT_FEATURES):
                weight = feature_weights.get(feature, 1.0)
                value = feature_values[feat_idx].item()  # Get scalar value
                contribution = value * weight
                logger.info(f"{feature:>10}: Value={value:.3f}, Weight={weight:.1f}, "
                          f"Contribution={contribution:.3f}")
            
            logger.info("\nPredictions vs Actuals (Original Scale):")
            for j, feature in enumerate(TARGET_FEATURES):
                pred = predictions[i][j]
                actual = actuals[i][j]
                diff = abs(pred - actual)
                logger.info(f"{feature:>10}: Pred={pred:.3f}, Act={actual:.3f}, "
                          f"Diff={diff:.3f}")
            logger.info("-" * 50)

# Test the model
test_model_predictions()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_29756\3021661028.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(checkpoint_path, map_location='cpu')
# INFO:__main__:
# Model Prediction Examples:
# INFO:__main__:
# Example 1:
# INFO:__main__:Feature Contributions (Last Sequence Value):
# INFO:__main__:   Top 100: Value=0.648, Weight=1.0, Contribution=0.648
# INFO:__main__:        FV: Value=-1.000, Weight=1.0, Contribution=-1.000
# INFO:__main__:
# Predictions vs Actuals (Original Scale):
# INFO:__main__:   WAR_150: Pred=-0.027, Act=-1.875, Diff=1.848
# INFO:__main__:--------------------------------------------------
# INFO:__main__:
# Example 2:
# INFO:__main__:Feature Contributions (Last Sequence Value):
# INFO:__main__:   Top 100: Value=-0.706, Weight=1.0, Contribution=-0.706
# INFO:__main__:        FV: Value=-0.412, Weight=1.0, Contribution=-0.412
# INFO:__main__:
# Predictions vs Actuals (Original Scale):
# INFO:__main__:   WAR_150: Pred=0.912, Act=3.529, Diff=2.617
# INFO:__main__:--------------------------------------------------
# INFO:__main__:
# Example 3:
# INFO:__main__:Feature Contributions (Last Sequence Value):
# INFO:__main__:   Top 100: Value=-0.888, Weight=1.0, Contribution=-0.888
# INFO:__main__:        FV: Value=-0.176, Weight=1.0, Contribution=-0.176
# INFO:__main__:
# Predictions vs Actuals (Original Scale):
# INFO:__main__:   WAR_150: Pred=1.503, Act=1.154, Diff=0.349
# INFO:__main__:--------------------------------------------------
# INFO:__main__:
# Example 4:
# INFO:__main__:Feature Contributions (Last Sequence Value):
# INFO:__main__:   Top 100: Value=-0.492, Weight=1.0, Contribution=-0.492
# INFO:__main__:        FV: Value=-0.882, Weight=1.0, Contribution=-0.882
# INFO:__main__:
# Predictions vs Actuals (Original Scale):
# INFO:__main__:   WAR_150: Pred=0.300, Act=0.000, Diff=0.300
# INFO:__main__:--------------------------------------------------
# INFO:__main__:
# Example 5:
# INFO:__main__:Feature Contributions (Last Sequence Value):
# INFO:__main__:   Top 100: Value=0.550, Weight=1.0, Contribution=0.550
# INFO:__main__:        FV: Value=-0.882, Weight=1.0, Contribution=-0.882
# INFO:__main__:
# Predictions vs Actuals (Original Scale):
# INFO:__main__:   WAR_150: Pred=-0.026, Act=-9.000, Diff=8.974
# INFO:__main__:--------------------------------------------------

# %%
def generate_batter_names(raw_df: pd.DataFrame, output_path: str = '../data/batter_names.csv'):
    """Generate and save a dataset of batter names and IDs"""
    try:
        # Get unique batter entries
        batter_names = raw_df[['Name', 'IDfg']].drop_duplicates()
        
        # Sort by Name for easier reference
        batter_names = batter_names.sort_values('Name')
        
        # Save to CSV
        batter_names.to_csv(output_path, index=False)
        logger.info(f"Saved {len(batter_names)} batter names to {output_path}")
        
        return batter_names
        
    except Exception as e:
        logger.error(f"Error generating batter names: {str(e)}")
        raise

# %%
def load_model_from_checkpoint(checkpoint_path: str, data_config, device: torch.device) -> nn.Module:
    """Load model with proper error handling and validation"""
    try:
        logger.info(f"Loading model from {checkpoint_path}")
        checkpoint = torch.load(checkpoint_path, map_location=device)
        
        # Initialize model with correct parameters
        model = ImprovedLSTM(
            input_size=len(data_config.input_features),
            hidden_size=256,
            num_layers=4,
            output_size=len(data_config.input_features),
            dropout=0.2,
            bidirectional=True,
            num_heads=4
        ).to(device)
        
        # Load state dict
        model.load_state_dict(checkpoint['model_state_dict'])
        model.eval()
        
        # Validate model configuration
        if hasattr(checkpoint, 'config'):
            logger.info(f"Loaded model config: {checkpoint['config']}")
        
        return model
        
    except FileNotFoundError:
        logger.error(f"Checkpoint file not found: {checkpoint_path}")
        raise
    except KeyError as e:
        logger.error(f"Invalid checkpoint structure: {str(e)}")
        raise
    except Exception as e:
        logger.error(f"Error loading model: {str(e)}")
        raise

def predict_future_stats(player_id, input_features, model, scaler, raw_df, player_names):
    """Predict future stats for a given player with support for rookies"""
    # Get player data
    player_data = raw_df[raw_df['IDfg'] == player_id].sort_values('Season')
    
    # Get player info
    player_name = player_names[player_names['IDfg'] == player_id]['Name'].iloc[0]
    last_season = player_data['Season'].max()
    last_age = player_data[player_data['Season'] == last_season]['Age'].iloc[0]
    
    logger.info(f"\nGenerating predictions for {player_name}")
    logger.info(f"Last season: {last_season}, Last age: {last_age}")
    
    # Get device from model
    device = next(model.parameters()).device
    
    # Handle players with less than 3 seasons
    num_seasons = len(player_data)
    if num_seasons < 3:
        # For players with 1-2 seasons, pad with their available data
        recent_data = player_data[input_features].copy()
        while len(recent_data) < 3:
            # Duplicate their most recent season
            recent_data = pd.concat([recent_data, recent_data.iloc[-1:]])
    else:
        # Use last 3 seasons for established players
        recent_data = player_data[input_features].iloc[-3:].copy()
    
    # Calculate career stats from available data
    career_stats = player_data[input_features].mean()
    
    # Create enhanced features with career stats
    enhanced_features = []
    for idx, row in recent_data.iterrows():
        career_dev = row - career_stats
        combined = np.concatenate([row.values, career_dev.values])
        enhanced_features.append(combined)
    
    sequence = np.array(enhanced_features)
    sequence_scaled = scaler.transform(sequence)
    
    # Dynamically get feature dimensions
    n_features = len(input_features)
    sequence_scaled = sequence_scaled[:, :n_features]
    
    predictions = []
    with torch.no_grad():
        for year_offset in range(1, 16):
            current_year = last_season + year_offset
            current_age = last_age + year_offset
            
            data = torch.FloatTensor(sequence_scaled).unsqueeze(0).to(device)
            lengths = torch.tensor([3], dtype=torch.int64, device=device)
            
            output = model(data, lengths)
            pred_numpy = output.cpu().numpy()[0]
            
            # Dynamic padding based on scaler dimensions
            scaler_dim = scaler.n_features_in_
            pred_padded = np.pad(pred_numpy, (0, scaler_dim - n_features), 'constant')
            unscaled_pred = scaler.inverse_transform(pred_padded.reshape(1, -1))[0][:n_features]
            
            prediction = {
                'Name': player_name,
                'Age': current_age,
                'Year': current_year,
                'IDfg': player_id
            }
            
            for i, feature in enumerate(input_features):
                if feature == 'Age':
                    prediction[feature] = current_age
                else:
                    prediction[feature] = unscaled_pred[i]
            
            predictions.append(prediction)
            
            # Update sequence for next prediction
            age_index = input_features.index('Age')
            age_update = np.zeros(scaler_dim)
            age_update[age_index] = current_age
            pred_numpy[age_index] = scaler.transform([age_update])[0][age_index]
            sequence_scaled = np.vstack([sequence_scaled[1:], pred_numpy])
    
    return predictions

def predict_all_2024_players(raw_df, player_names, model, scaler, input_features):
    """Predict future stats with proper feature dimension handling"""
    logger.info("Starting predictions for all 2024 players")
    
    # Get all players from 2024 with minimum PA
    players_2024 = raw_df[
        (raw_df['Season'] == 2024) & 
        (raw_df['PA'] >= 100)
    ]['IDfg'].unique()
    
    logger.info(f"Found {len(players_2024)} players from 2024")
    
    all_predictions = []
    
    for player_id in tqdm(players_2024):
        try:
            predictions = predict_future_stats(
                player_id=player_id,
                input_features=input_features,
                model=model,
                scaler=scaler,
                raw_df=raw_df,
                player_names=player_names
            )
            if predictions:
                all_predictions.extend(predictions)
        except Exception as e:
            logger.error(f"Error predicting for player {player_id}: {str(e)}")
            continue
    
    # Create DataFrame only if predictions exist
    predictions_df = pd.DataFrame(all_predictions) if all_predictions else None
    
    if predictions_df is not None:
        # Save separate CSV for each year
        for year in range(2025, 2040):
            year_predictions = predictions_df[predictions_df['Year'] == year].copy()
            year_predictions = year_predictions.sort_values('wRC+', ascending=False)
            filename = f'../data/generated/Batter_Predictions_{year}.csv'
            year_predictions.to_csv(filename, index=False)
            logger.info(f"Saved predictions for {year} to {filename}")
        return predictions_df
    else:
        logger.warning("No predictions were generated")
        return None

# Load data and model
raw_df = pd.read_csv('../data/mlb_batting_data_2010_2024.csv')
player_names = generate_batter_names(raw_df)  # Replace loading CSV with function call
scaler = joblib.load('batter_scaler.pkl')

# Initialize configuration with both existing and new rate stats
data_config = DataConfig(
    input_features = [
                # Base features
                'Age', 'BB%', 'K%', 'BABIP', 'AVG', 'OBP', 'SLG', 'wOBA', 'wRC+',
                #'Barrel%', 'HardHit%', #'EV',
                #'GB%', 'FB%', 'LD%', 'Pull%', 'Oppo%', 'O-Swing%', 'Z-Swing%',
                #'Swing%', 'O-Contact%', 'Z-Contact%','Contact%', 'SwStr%', 'CSW%', 'TTO%',
                #Rate stats
                'HR_rate', '2B_rate', '3B_rate', 'RBI_rate', 'R_rate'#, 'G', 'PA'
            ]
)

# Modify the raw dataframe to include rate stats before loading model
raw_df = calculate_rate_stats(raw_df)

# Rest of the code remains the same
model = load_model_from_checkpoint(
    checkpoint_path='checkpoints/batter_model.pth',
    data_config=data_config,
    device=device
)

predictions_df = predict_all_2024_players(
    raw_df=raw_df,
    player_names=player_names,  # Now using the generated player_names
    model=model,
    scaler=scaler,
    input_features=data_config.input_features
)

if predictions_df is not None:
    print("\nTop 10 Predicted Performers for 2025:")
    print(predictions_df[predictions_df['Year'] == 2025][
        ['Name', 'Age', 'wRC+']  # Added rate stats to output
    ].head(10))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[107], line 171
#     168         return None
#     170 # Load data and model
# --> 171 raw_df = pd.read_csv('../data/mlb_batting_data_2010_2024.csv')
#     172 player_names = generate_batter_names(raw_df)  # Replace loading CSV with function call
#     173 scaler = joblib.load('batter_scaler.pkl')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/mlb_batting_data_2010_2024.csv'

# %%
# 1. Required imports
from pathlib import Path
import pandas as pd
import numpy as np
import logging
from typing import Dict, List

# 2. Constants and paths
PREDICTION_YEARS = range(2025, 2040)
ROOT_DIR = Path.cwd().parent
DATA_DIR = ROOT_DIR / 'data'
GENERATED_DIR = DATA_DIR / 'generated'

GAMES_PER_SEASON = 150
CATCHER_GAMES = 135
INNINGS_PER_GAME = 9
POS_ADJUSTMENTS = {
    'C': 12.5, '1B': -12.5, '2B': 2.5, '3B': 2.5, 'SS': 7.5,
    'LF': -7.5, 'CF': 2.5, 'RF': -7.5, 'DH': -17.5
}
IF_BASE_RUN_VALUE = 0.75
OF_BASE_RUN_VALUE = 0.90

# Position-specific run value adjustments
POS_RUN_ADJUSTMENTS = {
    'SS': -0.005,
    '2B': -0.005,
    '1B': 0.010,
    '3B': 0.010,
    'LF': 0,  # Will use OF_BASE_RUN_VALUE
    'CF': 0,  # Will use OF_BASE_RUN_VALUE
    'RF': 0,  # Will use OF_BASE_RUN_VALUE
}
INFIELD_STATS = ['DRS/150', 'UZR/150', 'OAA/150', 'RngR/150', 'ErrR/150', 'DPR/150']
OUTFIELD_STATS = ['DRS/150', 'UZR/150', 'OAA/150', 'ARM/150', 'RngR/150']
CATCHER_STATS = ['DRS/150', 'FRM/150', 'rSB/150', 'rCERA/150']


# 3. Defensive value calculations
def calculate_defensive_value(df: pd.DataFrame) -> pd.DataFrame:
    """Calculate defensive value using Tangotiger's research."""
    
    df['inn_pct'] = df.groupby(['IDfg', 'Year'])['Inn'].transform(lambda x: x / x.sum())
    df['projected_inn'] = df.apply(
        lambda row: (CATCHER_GAMES if row['Pos'] == 'C' else GAMES_PER_SEASON) * 
        INNINGS_PER_GAME * row['inn_pct'], 
        axis=1
    )
    
    def get_run_value(row):
        pos = row['Pos']
        if pos in ['LF', 'CF', 'RF']:
            # Outfield calculation
            base_value = OF_BASE_RUN_VALUE
            return row['OAA/150'] * base_value * (row['projected_inn'] / (150 * 9))
        elif pos in ['SS', '2B', '1B', '3B']:
            # Infield calculation
            base_value = IF_BASE_RUN_VALUE
            pos_adjustment = POS_RUN_ADJUSTMENTS.get(pos, 0)
            return row['OAA/150'] * (base_value + pos_adjustment) * (row['projected_inn'] / (150 * 9))
        elif pos == 'C':
            # Catcher calculation - using traditional positional adjustment
            return ((row['DRS/150'] + row['FRM/150']) * (CATCHER_GAMES/150))
        else:
            return 0
    
    df['run_value'] = df.apply(get_run_value, axis=1)
    
    # Add positional adjustments
    df['pos_adjustment'] = df['Pos'].map(POS_ADJUSTMENTS)
    df['def_value'] = df['run_value'] + df['pos_adjustment']
    
    return df.groupby(['IDfg', 'Year'])['def_value'].sum().reset_index()


# 4. Position determination
def determine_position(group_df: pd.DataFrame) -> str:
    """Determine player's position(s) based on innings played."""
    if group_df.empty or group_df['Inn'].sum() == 0:
        return 'DH'
        
    # Calculate position percentages
    total_inn = group_df['Inn'].sum()
    pos_pct = group_df.groupby('Pos')['Inn'].sum() / total_inn
    
    # Primary position check (>70%)
    primary_pos = pos_pct[pos_pct > 0.7]
    if not primary_pos.empty:
        return primary_pos.index[0]
    
    # OF combination check
    outfield_mask = pos_pct.index.isin(['LF', 'CF', 'RF'])
    of_pct = pos_pct[outfield_mask].sum()
    if of_pct > 0.7:
        return 'OF'
    
    # Multi-position check
    top_two = pos_pct.nlargest(2)
    if len(top_two) > 1 and top_two.iloc[1] > 0.2:
        return f"{top_two.index[0]}/{top_two.index[1]}"
    
    return top_two.index[0]

# 5. Load and process data
def process_fielding_data() -> pd.DataFrame:
    """Process fielding data with defensive metrics."""
    # Load data
    dfs = []
    for year in PREDICTION_YEARS:
        file_path = GENERATED_DIR / f"Fielding_Predictions_{year}.csv"
        df = pd.read_csv(file_path)
        df['Year'] = year
        dfs.append(df)
    
    fielding_data = pd.concat(dfs, ignore_index=True)
    
    # Calculate defensive values
    defensive_values = calculate_defensive_value(fielding_data)
    
    # Determine positions
    positions = fielding_data.groupby(['IDfg', 'Year']).apply(determine_position).reset_index(name='Position')
    
    # Load batter predictions to get all player-seasons
    batter_dfs = []
    for year in PREDICTION_YEARS:
        file_path = GENERATED_DIR / f"Batter_Predictions_{year}.csv"
        df = pd.read_csv(file_path)
        df['Year'] = year
        batter_dfs.append(df)
    
    all_batters = pd.concat(batter_dfs, ignore_index=True)[['IDfg', 'Year']]
    
    # Merge with fielding data and fill missing values
    result = (all_batters.merge(defensive_values, on=['IDfg', 'Year'], how='left')
              .merge(positions, on=['IDfg', 'Year'], how='left'))
    
    # Fill NaN values for DHs
    result['Position'] = result['Position'].fillna('DH')
    result['def_value'] = result['def_value'].fillna(POS_ADJUSTMENTS['DH'])
    
    return result
def aggregate_position_stats(group_df: pd.DataFrame) -> pd.Series:
    """Aggregate position-specific defensive stats."""
    stats = {}
    
    # Infield stats
    if_data = group_df[group_df['Pos'].isin(['SS', '2B', '3B', '1B'])]
    for stat in INFIELD_STATS:
        if not if_data.empty:
            stats[f'IF_{stat}'] = if_data[stat].mean()
    
    # Outfield stats
    of_data = group_df[group_df['Pos'].isin(['LF', 'CF', 'RF'])]
    for stat in OUTFIELD_STATS:
        if not of_data.empty:
            stats[f'OF_{stat}'] = of_data[stat].mean()
    
    # Catcher stats
    c_data = group_df[group_df['Pos'] == 'C']
    for stat in CATCHER_STATS:
        if not c_data.empty:
            stats[f'C_{stat}'] = c_data[stat].mean()
    
    return pd.Series(stats)

# Execute
try:
    fielding_results = process_fielding_data()
    print(f"Processed {len(fielding_results)} player-seasons")
    print("\nPosition distribution:")
    print(fielding_results['Position'].value_counts())
except Exception as e:
    logging.error(f"Error processing fielding data: {e}")
    raise
# Out:
# Processed 6825 player-seasons
#
# Position distribution:
# Position
# DH       931
# C        885
# 1B       644
# 3B       616
# SS       585
# 2B       585
# CF       555
# RF       540
# LF       480
# OF       466
# 3B/2B     69
# 2B/SS     52
# 2B/3B     52
# 1B/RF     43
# 3B/SS     38
# 1B/3B     36
# SS/3B     32
# 2B/LF     30
# 3B/CF     28
# SS/2B     27
# 1B/2B     26
# 2B/1B     19
# 1B/LF     16
# SS/CF     15
# 1B/C      15
# 2B/RF     15
# SS/RF     15
# 3B/1B      8
# 3B/RF      2
# Name: count, dtype: int64

# %%
predictions_df = predictions_df.merge(
    fielding_results[['IDfg', 'Year', 'def_value', 'Position']], 
    on=['IDfg', 'Year'], 
    how='left'
)

# %%
def load_baserunning_data():
    """Load baserunning predictions for all years"""
    dfs = []
    for year in range(2025, 2040):
        filepath = f'../data/generated/Baserunning_Predictions_{year}.csv'
        df = pd.read_csv(filepath)
        df['Year'] = year
        dfs.append(df)
    return pd.concat(dfs, ignore_index=True)

# Load baserunning data and merge with existing predictions
baserunning_df = load_baserunning_data()
predictions_df = predictions_df.merge(
    baserunning_df[['IDfg', 'Year', 'wSB_rate', 'UBR_rate', 'wGDP_rate', 'SB_rate', 'CS_rate']], 
    on=['IDfg', 'Year'], 
    how='left'
)

# %%
def calculate_baserunning_value(predictions_df):
    """Calculate baserunning value with position-based games adjustment"""
    # Deep copy to avoid modifying original
    df = predictions_df.copy()
    
    # Adjust games based on position
    df['Games'] = df['Position'].map(lambda x: 135 if x == 'C' else 150)
    
    # Calculate BsR components using rate stats * games
    df['wSB'] = df['wSB_rate'] * df['Games']
    df['UBR'] = df['UBR_rate'] * df['Games']
    df['wGDP'] = df['wGDP_rate'] * df['Games']
    
    # Calculate total BsR
    df['BsR'] = df['wSB'] + df['UBR'] + df['wGDP']
    
    # Calculate counting stats for SB/CS
    df['SB'] = round(df['SB_rate'] * df['Games'])
    df['CS'] = round(df['CS_rate'] * df['Games'])
    
    # Add BsR components and counting stats to original dataframe
    cols_to_add = ['BsR', 'wSB', 'UBR', 'wGDP', 'SB', 'CS']
    for col in cols_to_add:
        predictions_df[col] = df[col]
    
    return predictions_df

# Process predictions
if predictions_df is not None:
    predictions_df = calculate_baserunning_value(predictions_df)

# %%
def calculate_war_components(row, pos_games_map={'C': 135}, default_games=150):
    """Calculate WAR components with position-specific playing time"""
    # Position-based games
    games = pos_games_map.get(row['Position'], default_games)
    pa = games * 4.2

    # Hitting counting stats
    hitting_stats = {}
    for stat in ['HR', '2B', '3B', 'RBI', 'R']:
        if f'{stat}_rate' in row:
            hitting_stats[stat] = round(row[f'{stat}_rate'] * games, 1)

    # WAR components
    wOBA_scale = 1.23
    lg_wOBA = 0.309
    RPW = 9.8
    lgPA = 186188

    Off = ((row['wOBA'] - lg_wOBA) / wOBA_scale) * pa
    Def = row['def_value']
    BsR = row['BsR']
    rep_level = 570 * RPW * pa / lgPA
    
    # BsR already calculated in previous step
    rar = Off + row['BsR'] + Def + rep_level
    war = rar / RPW

    return war, {
        'Off': Off,
        'BsR': BsR,
        'Def': Def,
        'WAR': war,
        'PA': pa,
        'G': games,
        **hitting_stats,
        'SB': row['SB'],
        'CS': row['CS']
    }

def calculate_war_for_predictions(predictions_df):
    """Add WAR and its components to predictions dataframe"""
    # Initialize WAR components (exclude BsR - already calculated)
    war_components = ['Off', 'Def', 'WAR']
    for col in war_components:
        predictions_df[col] = 0.0
    
    pos_games_map = {'C': 135}
    default_games = 150
    
    # Calculate WAR components
    for idx, row in predictions_df.iterrows():
        _, components = calculate_war_components(
            row, 
            pos_games_map=pos_games_map,
            default_games=default_games
        )
        for component, value in components.items():
            if component != 'BsR':  # Preserve existing BsR
                predictions_df.at[idx, component] = value
    
    # Remove all rate statistics after calculations
    rate_columns = [col for col in predictions_df.columns 
                   if col.endswith('_rate')]
    predictions_df = predictions_df.drop(columns=rate_columns)
    
    return predictions_df

# After generating predictions, calculate WAR and save to CSVs
if predictions_df is not None:
    predictions_df = calculate_war_for_predictions(predictions_df)
    
    # Save predictions with WAR components to separate year CSVs
    for year in range(2025, 2040):
        # Load existing file
        filename = f'../data/generated/Batter_Predictions_{year}.csv'
        year_predictions = predictions_df[predictions_df['Year'] == year].copy()
        
        # Sort by WAR
        year_predictions = year_predictions.sort_values('WAR', ascending=False)
        
        # Select columns to save, including new WAR components
        cols_to_save = [col for col in year_predictions.columns if col not in ['RAR', 'rep_level']]
        
        # Save updated predictions
        year_predictions[cols_to_save].to_csv(filename, index=False)
        logger.info(f"Saved predictions with WAR components for {year} to {filename}")
    
    # Display results
    print("\nTop 10 Predicted WAR for 2025:")
    display_cols = ['Name', 'Age', 'wOBA', 'wRC+', 'WAR', 'Off', 'BsR', 'Def']
    print(predictions_df[predictions_df['Year'] == 2025][display_cols]
          .sort_values('WAR', ascending=False).head(10))
# Out:
# INFO:__main__:Saved predictions with WAR components for 2025 to ../data/generated/Batter_Predictions_2025.csv
# INFO:__main__:Saved predictions with WAR components for 2026 to ../data/generated/Batter_Predictions_2026.csv
# INFO:__main__:Saved predictions with WAR components for 2027 to ../data/generated/Batter_Predictions_2027.csv
# INFO:__main__:Saved predictions with WAR components for 2028 to ../data/generated/Batter_Predictions_2028.csv
# INFO:__main__:Saved predictions with WAR components for 2029 to ../data/generated/Batter_Predictions_2029.csv
# INFO:__main__:Saved predictions with WAR components for 2030 to ../data/generated/Batter_Predictions_2030.csv
# INFO:__main__:Saved predictions with WAR components for 2031 to ../data/generated/Batter_Predictions_2031.csv
# INFO:__main__:Saved predictions with WAR components for 2032 to ../data/generated/Batter_Predictions_2032.csv
# INFO:__main__:Saved predictions with WAR components for 2033 to ../data/generated/Batter_Predictions_2033.csv
# INFO:__main__:Saved predictions with WAR components for 2034 to ../data/generated/Batter_Predictions_2034.csv
# INFO:__main__:Saved predictions with WAR components for 2035 to ../data/generated/Batter_Predictions_2035.csv
# INFO:__main__:Saved predictions with WAR components for 2036 to ../data/generated/Batter_Predictions_2036.csv
# INFO:__main__:Saved predictions with WAR components for 2037 to ../data/generated/Batter_Predictions_2037.csv
# INFO:__main__:Saved predictions with WAR components for 2038 to ../data/generated/Batter_Predictions_2038.csv
# INFO:__main__:Saved predictions with WAR components for 2039 to ../data/generated/Batter_Predictions_2039.csv
# Top 10 Predicted WAR for 2025:
#                   Name  Age      wOBA        wRC+       WAR        Off  \
# 0          Aaron Judge   33  0.428401  179.008026  8.304615  61.156499
# 165  William Contreras   27  0.361985  129.995316  6.243960  24.424998
# 60    Gunnar Henderson   24  0.359697  128.225296  6.180959  25.967008
# 15      Bobby Witt Jr.   25  0.353496  121.936287  6.055366  22.790398
# 300       Corey Seager   31  0.366654  133.698364  5.651254  29.529873
# 75    Francisco Lindor   31  0.348547  120.812950  5.568754  20.255756
# 105       Jose Ramirez   32  0.355152  125.464638  5.283673  23.638850
# 30       Shohei Ohtani   30  0.392397  151.553497  5.204804  42.715575
# 390        Kyle Tucker   28  0.375392  140.262329  5.197237  34.005852
# 195        Cal Raleigh   28  0.317828  100.349792  5.139513   4.069589
#
#           BsR        Def
# 0    0.026890   1.300619
# 165 -2.460437  22.215148
# 60   4.036271  11.668900
# 15   6.255207  11.395767
# 300 -1.925481   8.876683
# 75   4.381755  11.035059
# 105  5.141919   4.098010
# 30   6.890287 -17.500000
# 390  4.417319  -6.391466
# 195 -1.477162  30.763709
